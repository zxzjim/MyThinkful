# %% [markdown]
# # Importing Libraries and Data

# %%
# %matplotlib inline
import numba

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
from IPython.display import display

from nltk.tokenize import word_tokenize, RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk import FreqDist
from nltk.corpus import wordnet as wn

import string
# Out:
# /Users/zhangxinzhou/anaconda/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
attributes_raw = pd.read_csv('attributes.csv')
product_desc_raw = pd.read_csv('product_descriptions.csv')
test_raw = pd.read_csv('test.csv')
train_raw = pd.read_csv('train.csv')

# %%
attributes_raw.head(20)
# Out:
#     product_uid                    name  \
# 0      100001.0                Bullet01
# 1      100001.0                Bullet02
# 2      100001.0                Bullet03
# 3      100001.0                Bullet04
# 4      100001.0                Bullet05
# 5      100001.0                Bullet06
# 6      100001.0                Bullet07
# 7      100001.0                   Gauge
# 8      100001.0                Material
# 9      100001.0          MFG Brand Name
# 10     100001.0        Number of Pieces
# 11     100001.0     Product Depth (in.)
# 12     100001.0    Product Height (in.)
# 13     100001.0    Product Weight (lb.)
# 14     100001.0     Product Width (in.)
# 15     100002.0      Application Method
# 16     100002.0   Assembled Depth (in.)
# 17     100002.0  Assembled Height (in.)
# 18     100002.0   Assembled Width (in.)
# 19     100002.0                Bullet01
#
#                                                 value
# 0   Versatile connector for various 90° connection...
# 1   Stronger than angled nailing or screw fastenin...
# 2   Help ensure joints are consistently straight a...
# 3               Dimensions: 3 in. x 3 in. x 1-1/2 in.
# 4                            Made from 12-Gauge steel
# 5           Galvanized for extra corrosion resistance
# 6   Install with 10d common nails or #9 x 1-1/2 in...
# 7                                                  12
# 8                                    Galvanized Steel
# 9                                  Simpson Strong-Tie
# 10                                                  1
# 11                                                1.5
# 12                                                  3
# 13                                               0.26
# 14                                                  3
# 15                                 Brush,Roller,Spray
# 16                                            6.63 in
# 17                                            7.76 in
# 18                                            6.63 in
# 19  Revives wood and composite decks, railings, po...

# %%
attributes_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2044803 entries, 0 to 2044802
# Data columns (total 3 columns):
# product_uid    float64
# name           object
# value          object
# dtypes: float64(1), object(2)
# memory usage: 46.8+ MB

# %%
product_desc_raw.head(20)
# Out:
#     product_uid                                product_description
# 0        100001  Not only do angles make joints stronger, they ...
# 1        100002  BEHR Premium Textured DECKOVER is an innovativ...
# 2        100003  Classic architecture meets contemporary design...
# 3        100004  The Grape Solar 265-Watt Polycrystalline PV So...
# 4        100005  Update your bathroom with the Delta Vero Singl...
# 5        100006  Achieving delicious results is almost effortle...
# 6        100007  The Quantum Adjustable 2-Light LED Black Emerg...
# 7        100008  The Teks #10 x 1-1/2 in. Zinc-Plated Steel Was...
# 8        100009  Get the House of Fara 3/4 in. x 3 in. x 8 ft. ...
# 9        100010  Valley View Industries Metal Stakes (4-Pack) a...
# 10       100011  Recycler 22 in. Personal Pace Variable Speed S...
# 11       100012  The 96 in. wide Caramel Simple Weave Rollup Ba...
# 12       100013  The InSinkErator SinkTop Switch Single Outlet ...
# 13       100014  The Rubbermaid 1-Step Folding Plastic Step Sto...
# 14       100015  Backyard X-Scapes, Inc. uses the finest bamboo...
# 15       100016  Make grilling great with this handsome and fun...
# 16       100017  The MD Building Products 36 in. x 36 in. x 1/5...
# 17       100018  This classic plastic sprinkler head that fits ...
# 18       100019  The House of Fara 8 Linear ft. primed MDF Over...
# 19       100020  These unique LED multi-color sticks are sure t...

# %%
product_desc_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124428 entries, 0 to 124427
# Data columns (total 2 columns):
# product_uid            124428 non-null int64
# product_description    124428 non-null object
# dtypes: int64(1), object(1)
# memory usage: 1.9+ MB

# %%
train_raw.head(20)
# Out:
#     id  product_uid                                      product_title  \
# 0    2       100001                  Simpson Strong-Tie 12-Gauge Angle
# 1    3       100001                  Simpson Strong-Tie 12-Gauge Angle
# 2    9       100002  BEHR Premium Textured DeckOver 1-gal. #SC-141 ...
# 3   16       100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 4   17       100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 5   18       100006  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 6   20       100006  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 7   21       100006  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 8   23       100007  Lithonia Lighting Quantum 2-Light Black LED Em...
# 9   27       100009  House of Fara 3/4 in. x 3 in. x 8 ft. MDF Flut...
# 10  34       100010       Valley View Industries Metal Stakes (4-Pack)
# 11  35       100011  Toro Personal Pace Recycler 22 in. Variable Sp...
# 12  37       100011  Toro Personal Pace Recycler 22 in. Variable Sp...
# 13  38       100011  Toro Personal Pace Recycler 22 in. Variable Sp...
# 14  48       100012  Hampton Bay Caramel Simple Weave Bamboo Rollup...
# 15  51       100013  InSinkErator SinkTop Switch Single Outlet for ...
# 16  65       100016  Sunjoy Calais 8 ft. x 5 ft. x 8 ft. Steel Tile...
# 17  69       100017  MD Building Products 36 in. x 36 in. Cloverlea...
# 18  75       100017  MD Building Products 36 in. x 36 in. Cloverlea...
# 19  81       100017  MD Building Products 36 in. x 36 in. Cloverlea...
#
#                            search_term  relevance
# 0                        angle bracket       3.00
# 1                            l bracket       2.50
# 2                            deck over       3.00
# 3                     rain shower head       2.33
# 4                   shower only faucet       2.67
# 5                       convection otr       3.00
# 6                 microwave over stove       2.67
# 7                           microwaves       3.00
# 8                      emergency light       2.67
# 9                              mdf 3/4       3.00
# 10                        steele stake       2.67
# 11      briggs and stratton lawn mower       3.00
# 12                            gas mowe       3.00
# 13                         honda mower       2.00
# 14  hampton bay chestnut pull up shade       2.67
# 15                            disposer       2.67
# 16                        grill gazebo       3.00
# 17                         door guards       1.00
# 18              metal plate cover gcfi       1.67
# 19                      radiator grate       2.33

# %%
train_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74067 entries, 0 to 74066
# Data columns (total 5 columns):
# id               74067 non-null int64
# product_uid      74067 non-null int64
# product_title    74067 non-null object
# search_term      74067 non-null object
# relevance        74067 non-null float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 2.8+ MB

# %%
test_raw.head(20)
# Out:
#     id  product_uid                                      product_title  \
# 0    1       100001                  Simpson Strong-Tie 12-Gauge Angle
# 1    4       100001                  Simpson Strong-Tie 12-Gauge Angle
# 2    5       100001                  Simpson Strong-Tie 12-Gauge Angle
# 3    6       100001                  Simpson Strong-Tie 12-Gauge Angle
# 4    7       100001                  Simpson Strong-Tie 12-Gauge Angle
# 5    8       100001                  Simpson Strong-Tie 12-Gauge Angle
# 6   10       100003  STERLING Ensemble 33-1/4 in. x 60 in. x 75-1/4...
# 7   11       100003  STERLING Ensemble 33-1/4 in. x 60 in. x 75-1/4...
# 8   12       100003  STERLING Ensemble 33-1/4 in. x 60 in. x 75-1/4...
# 9   13       100004  Grape Solar 265-Watt Polycrystalline Solar Pan...
# 10  14       100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 11  15       100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 12  19       100006  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 13  22       100006  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 14  24       100008  Teks #10 1-1/2 in. External Hex Flange Hex-Hea...
# 15  25       100009  House of Fara 3/4 in. x 3 in. x 8 ft. MDF Flut...
# 16  26       100009  House of Fara 3/4 in. x 3 in. x 8 ft. MDF Flut...
# 17  28       100010       Valley View Industries Metal Stakes (4-Pack)
# 18  29       100010       Valley View Industries Metal Stakes (4-Pack)
# 19  30       100010       Valley View Industries Metal Stakes (4-Pack)
#
#                        search_term
# 0                90 degree bracket
# 1                 metal l brackets
# 2                 simpson sku able
# 3             simpson strong  ties
# 4        simpson strong tie hcc668
# 5                  wood connectors
# 6              bath and shower kit
# 7                   bath drain kit
# 8             one piece tub shower
# 9                      solar panel
# 10  1 handle shower delta trim kit
# 11     delta ashland shower faucet
# 12                   cooking stove
# 13           microwaves over range
# 14             self tapping screws
# 15               3 1/20door casing
# 16                       door trim
# 17                   anchor stakes
# 18                landscape edging
# 19                     lawn edging

# %% [markdown]
# # Data Wrangling

# %%
train_merged = train_raw.merge(product_desc_raw, on='product_uid', how='left')
train_merged.tail(20)
# Out:
#            id  product_uid                                      product_title  \
# 74047  221413       206601  3M Tekk Protection White Vented Hard Hat with ...
# 74048  221415       206602  Hy-Lite Glass Block Fixed Vinyl Windows Driftw...
# 74049  221416       206603  Westinghouse 3 ft. Oil Rubbed Bronze Beaded Ch...
# 74050  221419       206606  BEHR Premium Plus #ICC-101 Florentine Clay Zer...
# 74051  221420       206607  Home Legend Palace Oak Light 3/4 in. Thick x 3...
# 74052  221422       206609  Whitehaus Collection Isabella Wall-Mounted Bat...
# 74053  221423       206610  Champion Power Equipment 6.5 HP Gas-Powered 3 ...
# 74054  221426       206613                    Everbilt 4 in. White Wall Guard
# 74055  221427       206614  Daltile Villa Valleta Calais Springs 18 in. x ...
# 74056  221432       206619  Home Styles Stone Harbor 51 in. Round 7-Piece ...
# 74057  221434       206621  Crown Bolt M6-32 x 90 mm. Internal Hex Socket ...
# 74058  221443       206627           25 in. Stainless Tip-Out Sink Front Tray
# 74059  221449       206631  Masonite New Haven Three Quarter Oval Lite Pri...
# 74060  221450       206632  Lilly Miller UltraGreen 1 Gal. Vitamin B-1 Pla...
# 74061  221455       206637  Schluter Rondec Stainless Steel 3/8 in. x 1 in...
# 74062  221457       206638  Atlantic Windowpane 576 CD or 192 DVD Blu-Ray ...
# 74063  221458       206639  Philips 40-Watt Halogen R20 Flood Light Bulb (...
# 74064  221463       206641  Schlage Camelot In-Active Aged Bronze Handlese...
# 74065  221471       206648  Plastec 11 in. x 24 in. Rose Garden Wall Decor...
# 74066  221473       206650  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
#
#                                       search_term  relevance  \
# 74047                        hard hat with mining       1.67
# 74048    replace a broken glass in a vinyl window       2.00
# 74049                 ceiling fan with chain cord       1.00
# 74050                             florentine clay       2.33
# 74051                          trim a home lights       2.00
# 74052                     whitehaus bathroom sinl       2.33
# 74053                        6.5 hp gas generator       2.33
# 74054                      splash guard for  wall       2.00
# 74055                spicewood springs floor tile       1.67
# 74056                        laguna porcelin tile       2.00
# 74057                               m6 screw 90mm       2.67
# 74058                           sink tip-out tray       3.00
# 74059          fiberglass front doors by masonite       3.00
# 74060                          starter fertillzer       2.00
# 74061  rondec stainless steel 3/8 edge protection       3.00
# 74062                              tv riser glass       1.00
# 74063                           r20 halogen light       3.00
# 74064     schlage lock siena half dummy knob with       2.33
# 74065                           zen garden  decor       3.00
# 74066                fine sheer curtain 63 inches       2.33
#
#                                      product_description
# 74047  3M TEKK Protection Vented Pro Ratchet Hard Hat...
# 74048  Excellent privacy and decorative solution for ...
# 74049  This Westinghouse Lighting Oil Rubbed Bronze B...
# 74050  BEHR Premium Plus Zero VOC, Self-Priming Inter...
# 74051  Quarter round is typically placed in front of ...
# 74052  Beautify your bathroom or powder room with a W...
# 74053  The Champion Power Equipment 3 in. semi-trash ...
# 74054  The Everbilt 4 in. Wall Guard helps prevent da...
# 74055  This dal-tile villa valleta calais springs por...
# 74056  Stone Harbor 7-Piece Dining Set includes Large...
# 74057  Crown Bolt's metric socket cap screws are idea...
# 74058  Add a little luxury to otherwise wasted space ...
# 74059  Create an inviting, stylish entryway with the ...
# 74060  Lilly Miller UltraGreen Vitamin B-1 Plant Star...
# 74061  The EV/RO100E is a prefabricated corner for Ro...
# 74062  Atlantic, Inc. 94835722 Uniquely designed for ...
# 74063  Philips Energy Advantage lamps use less energy...
# 74064  The Schlage Camelot In-Active Aged Bronze Hand...
# 74065  The Rose Garden is inspired by the popular ear...
# 74066  No. 918 Millennial Ryan heathered texture semi...

# %%
def remove_non_ascii(s):
    printable = set(string.printable)
    return filter(lambda x: x in printable, s)

# %%
train_merged['product_title'] = train_merged['product_title'].apply(remove_non_ascii)
train_merged['product_description'] = train_merged['product_description'].apply(remove_non_ascii)
train_merged['search_term'] = train_merged['search_term'].apply(remove_non_ascii)

# %%
df = train_merged[train_merged['id']==1060]
print df
# Out:
#        id  product_uid                                      product_title  \
# 323  1060       100179  Paslode 3 in. x 0.120-Gauge 30 Galvanized Ring...
#
#                   search_term  relevance  \
# 323  galvanized framing nails       2.67
#
#                                    product_description
# 323  For exterior applications like framing of sill...

# %% [markdown]
# ## try to find the similarity among the search term and the description and product title

# %% [markdown]
# ### experiment on the single row:

# %%
texts = [train_merged.iloc[1,2].lower(), train_merged.iloc[1,3].lower(), train_merged.iloc[1,5].lower()]
texts
# Out:
# ['simpson strong-tie 12-gauge angle',
#  'l bracket',
#  'not only do angles make joints stronger, they also provide more consistent, straight corners. simpson strong-tie offers a wide variety of angles in various sizes and thicknesses to handle light-duty jobs or projects where a structural connection is needed. some can be bent (skewed) to match the project. for outdoor projects or those where moisture is present, use our zmax zinc-coated connectors, which provide extra resistance against corrosion (look for a "z" at the end of the model number).versatile connector for various 90 connections and home repair projectsstronger than angled nailing or screw fastening alonehelp ensure joints are consistently straight and strongdimensions: 3 in. x 3 in. x 1-1/2 in.made from 12-gauge steelgalvanized for extra corrosion resistanceinstall with 10d common nails or #9 x 1-1/2 in. strong-drive sd screws']

# %% [markdown]
# #### extract the text, tokenize the sentences and clean up the text

# %%
from nltk.tokenize import word_tokenize, RegexpTokenizer

# %%
#tokenize and remove punctuation
tokenizer = RegexpTokenizer(r'\w+')
texts_t = [tokenizer.tokenize(t) for t in texts]

# %%
#remove stopwords
from nltk.corpus import stopwords

def remove_stopwords(text):
    return [word for word in text if word not in stopwords.words('english')]
    
texts_t = map(remove_stopwords, texts_t)

# %%
#remove suffix of the words
from nltk.stem.wordnet import WordNetLemmatizer
def get_words_stem(tokenized_text):
    lemmatizer = WordNetLemmatizer()
    return map(lemmatizer.lemmatize, tokenized_text)

texts_t = map(get_words_stem, texts_t)

# %% [markdown]
# #### use freqdist() to check the frequencies of each word and compare it with the search term

# %%
from nltk import FreqDist

# %%
def get_freq_in_text(text, word):
#     print text
    freq = FreqDist(text)
    return freq[word]

# %%
texts_t
# Out:
# [['simpson', 'strong', 'tie', '12', 'gauge', 'angle'],
#  ['l', 'bracket'],
#  [u'angle',
#   'make',
#   u'joint',
#   'stronger',
#   'also',
#   'provide',
#   'consistent',
#   'straight',
#   u'corner',
#   'simpson',
#   'strong',
#   'tie',
#   u'offer',
#   'wide',
#   'variety',
#   u'angle',
#   'various',
#   u'size',
#   u'thickness',
#   'handle',
#   'light',
#   'duty',
#   u'job',
#   u'project',
#   'structural',
#   'connection',
#   'needed',
#   'bent',
#   'skewed',
#   'match',
#   'project',
#   'outdoor',
#   u'project',
#   'moisture',
#   'present',
#   'use',
#   'zmax',
#   'zinc',
#   'coated',
#   u'connector',
#   'provide',
#   'extra',
#   'resistance',
#   'corrosion',
#   'look',
#   'z',
#   'end',
#   'model',
#   'number',
#   'versatile',
#   'connector',
#   'various',
#   '90',
#   u'connection',
#   'home',
#   'repair',
#   'projectsstronger',
#   'angled',
#   'nailing',
#   'screw',
#   'fastening',
#   'alonehelp',
#   'ensure',
#   u'joint',
#   'consistently',
#   'straight',
#   'strongdimensions',
#   '3',
#   'x',
#   '3',
#   'x',
#   '1',
#   '1',
#   '2',
#   'made',
#   '12',
#   'gauge',
#   'steelgalvanized',
#   'extra',
#   'corrosion',
#   'resistanceinstall',
#   '10d',
#   'common',
#   u'nail',
#   '9',
#   'x',
#   '1',
#   '1',
#   '2',
#   'strong',
#   'drive',
#   'sd',
#   u'screw']]

# %%
for word in texts_t[1]:
    print word
    print 'freq in title: ', get_freq_in_text(texts_t[0], word)
    print 'freq in desc: ', get_freq_in_text(texts_t[2], word)
# Out:
# l
# freq in title:  0
# freq in desc:  0
# bracket
# freq in title:  0
# freq in desc:  0

# %% [markdown]
# #### use synsets module to check simlilarity

# %% [markdown]
#  ##### method:
# * text_words
#     * word
#     * word
#     * word
#     * word
#         * synset1 <-loop through each synset
#         * synset2
#         * synset3
#
#  compared to:
#     * ref_word
#         * synset1
#         * synset2
#
#  find the max similarity between eg word:synset1 and ref_word:synset2
#
#  append this simliarity into word's syn_sims
#
#  find the max similarity between word:synset2 and the ref_word's synsets
#  ...
#  until each synset in the word has found the max similarity to the ref_word
#
#  then return the max value of the word's syn_sims list to represent the similarity of the word to the ref_word

# %%
kw = texts_t[1][1]
kw
# Out:
# 'bracket'

# %%
kw_syn = wn.synsets(kw)
kw_syn
# Out:
# [Synset('bracket.n.01'),
#  Synset('bracket.n.02'),
#  Synset('bracket.n.03'),
#  Synset('bracket.n.04'),
#  Synset('bracket.v.01'),
#  Synset('bracket.v.02'),
#  Synset('bracket.v.03')]

# %%
def compare_synsets(synsets1, synsets2):
    comparisons = [syn1.path_similarity(syn2) for syn2 in synsets2 for syn1 in synsets1]
    comparisons = [v for v in comparisons if v is not None]
    return sum(comparisons)

# %%
def get_synsets(word):
    return wn.synsets(word)

# %%
def check_similarity_word_words(ref_word_synsets, words):
    synsets_of_all_words = [wn.synsets(word) for word in words]
#     print synsets_of_all_words
    sim_word_to_word  = [compare_synsets(ref_word_synsets, synsets) for synsets in synsets_of_all_words]
    return sum(sim_word_to_word)

# %%
print kw, kw_syn, texts_t[0]
sim_kw_title = check_similarity_word_words(kw_syn, texts_t[0])
kw, sim_kw_title
# Out:
# bracket [Synset('bracket.n.01'), Synset('bracket.n.02'), Synset('bracket.n.03'), Synset('bracket.n.04'), Synset('bracket.v.01'), Synset('bracket.v.02'), Synset('bracket.v.03')] ['simpson', 'strong', 'tie', '12', 'gauge', 'angle']
# ('bracket', 25.43110843404961)

# %% [markdown]
# * check similarity between search key word and the product description

# %%
sim_kw_desc = check_similarity_word_list(kw_syn, texts_t[2])
kw, sim_kw_desc
# Out:
# sim: 0.0833333333333
# sim: 0.0769230769231
# sim: 0.0714285714286
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0666666666667
# sim: 0.0555555555556
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0769230769231
# sim: 0.0588235294118
# sim: 0.0909090909091
# sim: 0.0666666666667
# sim: 0.0625
# sim: 0.0588235294118
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0833333333333
# sim: 0.0833333333333
# sim: 0.0769230769231
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0714285714286
# sim: 0.0769230769231
# sim: 0.0666666666667
# sim: 0.0625
# sim: 0.0769230769231
# sim: 0.0833333333333
# sim: 0.0714285714286
# sim: 0.0769230769231
# sim: 0.0833333333333
# sim: 0.0714285714286
# sim: 0.0714285714286
# sim: None
# sim: None
# sim: None
# sim: 0.0666666666667
# sim: 0.0588235294118
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0588235294118
# sim: 0.0909090909091
# sim: 0.0833333333333
# sim: 0.0714285714286
# sim: 0.0588235294118
# sim: 0.0833333333333
# sim: 0.0769230769231
# sim: 0.0588235294118
# sim: 0.0666666666667
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0833333333333
# sim: 0.111111111111
# sim: 0.0769230769231
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.1
# sim: 0.0714285714286
# sim: 0.0909090909091
# sim: 0.0833333333333
# sim: 0.0714285714286
# sim: 0.0909090909091
# sim: 0.0833333333333
# sim: 0.0769230769231
# sim: 0.0714285714286
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0909090909091
# sim: 0.1
# sim: 0.0714285714286
# sim: 0.0909090909091
# sim: 0.0909090909091
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0833333333333
# sim: 0.0833333333333
# sim: 0.0714285714286
# sim: 0.0909090909091
# sim: 0.0769230769231
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0555555555556
# sim: 0.0625
# sim: 0.0769230769231
# sim: 0.0909090909091
# sim: 0.0666666666667
# sim: 0.0909090909091
# sim: 0.0909090909091
# sim: 0.0769230769231
# sim: 0.0909090909091
# sim: 0.0666666666667
# sim: 0.0769230769231
# sim: 0.0909090909091
# sim: 0.0909090909091
# sim: 0.125
# sim: 0.0666666666667
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0833333333333
# sim: 0.0769230769231
# sim: 0.0666666666667
# sim: 0.0833333333333
# sim: 0.0714285714286
# sim: 0.0666666666667
# sim: 0.0666666666667
# sim: 0.0769230769231
# sim: 0.0769230769231
# sim: 0.0769230769231
# sim: 0.0833333333333
# sim: 0.0714285714286
# sim: 0.0769230769231
# sim: 0.0666666666667
# sim: 0.0833333333333
# sim: 0.0555555555556
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0769230769231
# sim: 0.0769230769231
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.111111111111
# sim: 0.0909090909091
# sim: 0.0714285714286
# sim: 0.0769230769231
# sim: 0.0769230769231
# sim: 0.1
# sim: 0.0666666666667
# sim: 0.0666666666667
# sim: 0.0714285714286
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0833333333333
# sim: 0.0526315789474
# sim: 0.0833333333333
# sim: 0.0714285714286
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0625
# sim: 0.0833333333333
# sim: 0.0625
# sim: 0.0588235294118
# sim: 0.166666666667
# sim: 0.0769230769231
# sim: 0.0833333333333
# sim: 0.0833333333333
# sim: 0.0833333333333
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0769230769231
# sim: 0.0769230769231
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0769230769231
# sim: 0.0769230769231
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0833333333333
# sim: 0.1
# sim: 0.0769230769231
# sim: 0.0769230769231
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0833333333333
# sim: 0.0909090909091
# sim: 0.0909090909091
# sim: 0.0769230769231
# sim: 0.0714285714286
# sim: 0.0769230769231
# sim: 0.0625
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0769230769231
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0714285714286
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0666666666667
# sim: 0.05
# sim: 0.0769230769231
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0833333333333
# sim: 0.0666666666667
# sim: 0.0666666666667
# sim: 0.0833333333333
# sim: 0.0909090909091
# sim: 0.0769230769231
# sim: 0.0714285714286
# sim: 0.0909090909091
# sim: 0.0769230769231
# sim: 0.0625
# sim: 0.0909090909091
# sim: 0.0714285714286
# sim: 0.0769230769231
# sim: 0.0833333333333
# sim: 0.0714285714286
# sim: 0.0909090909091
# sim: 0.0833333333333
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0833333333333
# sim: 0.333333333333
# sim: 0.0714285714286
# sim: 0.125
# sim: 0.0833333333333
# sim: 0.0909090909091
# sim: 0.0714285714286
# sim: 0.1
# sim: 0.0625
# sim: 0.0625
# sim: 0.0666666666667
# sim: 0.0714285714286
# sim: 0.0714285714286
# sim: 0.0909090909091
# sim: 0.0714285714286
# sim: 0.0666666666667
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0714285714286
# sim: 0.0666666666667
# sim: 0.0714285714286
# sim: 0.0666666666667
# sim: 0.0769230769231
# sim: 0.0769230769231
# sim: 0.0833333333333
# sim: 0.0714285714286
# sim: 0.0769230769231
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0833333333333
# sim: 0.25
# sim: 0.0769230769231
# sim: 0.142857142857
# sim: 0.166666666667
# sim: 0.0555555555556
# sim: 0.0769230769231
# sim: 0.0833333333333
# sim: 0.0909090909091
# sim: 0.0833333333333
# sim: 0.0666666666667
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0714285714286
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.333333333333
# sim: None
# sim: 0.111111111111
# sim: 0.0909090909091
# sim: 0.0714285714286
# sim: 0.0769230769231
# sim: 0.0769230769231
# sim: 0.1
# sim: 0.0666666666667
# sim: 0.0666666666667
# sim: 0.0714285714286
# sim: 0.0625
# sim: 0.0666666666667
# sim: 0.0833333333333
# sim: 0.0555555555556
# sim: 0.0833333333333
# sim: 0.0714285714286
# sim: 0.0833333333333
# sim: 0.0833333333333
# sim: 0.0625
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0666666666667
# sim: 0.0909090909091
# sim: 0.0714285714286
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0666666666667
# sim: 0.0526315789474
# sim: 0.0555555555556
# sim: 0.0588235294118
# sim: 0.0666666666667
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0625
# sim: 0.0666666666667
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0769230769231
# sim: 0.0588235294118
# sim: 0.0909090909091
# sim: 0.0666666666667
# sim: 0.0625
# sim: 0.0588235294118
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0833333333333
# sim: 0.0833333333333
# sim: 0.0769230769231
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.2
# sim: None
# sim: 0.333333333333
# sim: 0.333333333333
# sim: 0.0625
# sim: None
# sim: 0.2
# sim: None
# sim: 0.333333333333
# sim: 0.333333333333
# sim: 0.0625
# sim: None
# sim: 0.2
# sim: None
# sim: 0.2
# sim: None
# sim: 0.2
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.333333333333
# sim: None
# sim: 0.0588235294118
# sim: 0.111111111111
# sim: 0.0769230769231
# sim: 0.0769230769231
# sim: 0.1
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0666666666667
# sim: 0.05
# sim: 0.0769230769231
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0714285714286
# sim: 0.0769230769231
# sim: 0.0666666666667
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0666666666667
# sim: 0.0588235294118
# sim: 0.166666666667
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.2
# sim: None
# sim: 0.333333333333
# sim: 0.333333333333
# sim: 0.0625
# sim: None
# sim: 0.2
# sim: None
# sim: 0.2
# sim: None
# sim: 0.2
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0833333333333
# sim: 0.0625
# sim: 0.0666666666667
# sim: 0.0666666666667
# sim: 0.1
# sim: 0.0588235294118
# sim: 0.0666666666667
# sim: 0.0625
# sim: 0.0833333333333
# sim: 0.0666666666667
# sim: 0.0666666666667
# sim: 0.0555555555556
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# sim: 0.0588235294118
# sim: 0.0666666666667
# sim: 0.0526315789474
# sim: 0.0555555555556
# sim: 0.0588235294118
# sim: 0.0666666666667
# sim: None
# sim: None
# sim: None
# sim: None
# sim: None
# ('l',
#  {'1': 0.2,
#   '12': 0.3333333333333333,
#   '2': 0.2,
#   '3': 0.2,
#   '9': 0.2,
#   '90': 0.3333333333333333,
#   'also': None,
#   u'angle': 0.08333333333333333,
#   'angled': None,
#   'bent': 0.08333333333333333,
#   'coated': None,
#   'common': 0.06666666666666667,
#   'connection': 0.1111111111111111,
#   u'connector': 0.07142857142857142,
#   'consistent': None,
#   'consistently': None,
#   u'corner': 0.08333333333333333,
#   'corrosion': 0.07692307692307693,
#   'drive': 0.1,
#   'duty': 0.08333333333333333,
#   'end': 0.125,
#   'ensure': None,
#   'extra': 0.07692307692307693,
#   'fastening': 0.06666666666666667,
#   'gauge': 0.1111111111111111,
#   'handle': 0.07692307692307693,
#   'home': 0.08333333333333333,
#   u'job': 0.08333333333333333,
#   u'joint': 0.09090909090909091,
#   'light': 0.125,
#   'look': 0.09090909090909091,
#   'made': None,
#   'make': 0.06666666666666667,
#   'match': 0.16666666666666666,
#   'model': 0.08333333333333333,
#   'moisture': 0.08333333333333333,
#   u'nail': 0.16666666666666666,
#   'nailing': None,
#   'needed': None,
#   'number': 0.25,
#   u'offer': 0.1111111111111111,
#   'outdoor': None,
#   'present': 0.1,
#   u'project': 0.07692307692307693,
#   'provide': None,
#   'repair': 0.09090909090909091,
#   'resistance': 0.09090909090909091,
#   'screw': 0.06666666666666667,
#   'sd': 0.058823529411764705,
#   'simpson': 0.06666666666666667,
#   u'size': 0.1,
#   'skewed': None,
#   'straight': 0.08333333333333333,
#   'strong': None,
#   'stronger': None,
#   'structural': None,
#   u'thickness': 0.09090909090909091,
#   'tie': 0.09090909090909091,
#   'use': 0.09090909090909091,
#   'variety': 0.1,
#   'various': None,
#   'versatile': None,
#   'wide': None,
#   'x': 0.3333333333333333,
#   'z': 0.3333333333333333,
#   'zinc': 0.07692307692307693})

# %% [markdown]
# * mean values of the similarities

# %%
def cal_similarities_mean(similarities_list):
    sims = [v for k,v in similarities_list.iteritems()]
    #drop na
    sims = np.array([e for e in sims if e != None])
    return sims.mean()

# %%
sim_kw_title_mean =cal_similarities_mean(sim_kw_title)
print sim_kw_title_mean

sim_kw_desc_mean = cal_similarities_mean(sim_kw_desc)
print sim_kw_desc_mean
# Out:
# 0.137070707071
# 0.123636759482

# %% [markdown]
# ### run on all rows

# %%
def remove_stopwords(text):
    return np.array([word for word in text if word not in stopwords.words('english')])

def get_words_stem(tokenized_text):
    lemmatizer = WordNetLemmatizer()
    return map(lemmatizer.lemmatize, tokenized_text)

def compare_synsets(synsets1, synsets2):
    comparisons = [syn1.path_similarity(syn2) for syn2 in synsets2 for syn1 in synsets1]
    comparisons = [v for v in comparisons if v is not None]
    if len(comparisons) > 0:
        return max(comparisons)
    else:
        return 0

def get_synsets(word):
    return wn.synsets(word) 

def check_similarity_word_words(ref_word_synsets, words):
    synsets_of_all_words = [wn.synsets(word) for word in words]
#     print synsets_of_all_words
    sim_word_to_word  = [compare_synsets(ref_word_synsets, synsets) for synsets in synsets_of_all_words]
    return max(sim_word_to_word)

# %%
def find_search_similarity_title_desc(row,title_col_name,search_col_name, desc_col_name, mode):
    print 'row id: ', row.id
    texts = np.array([row[title_col_name],row[search_col_name],row[desc_col_name] ])
#     print texts

    #tokenize and remove punctuation
    tokenizer = RegexpTokenizer(r'\w+')
    texts_t = np.array([tokenizer.tokenize(t) for t in texts])
    
    #remove stopwords
    texts_t = map(remove_stopwords, texts_t)
    
    #remove suffix of the words
    texts_t = map(get_words_stem, texts_t)
    
    sim_kw_title_mean_all = {}
    sim_kw_desc_mean_all = {}
    
    for kw in texts_t[1]:
        print 'keyword: ', kw
        #get the synsets of the keyword
        kw_syn = wn.synsets(kw)
        #get the similarity matrix of kw:product_title
        sim_kw_title_mean = check_similarity_word_words(kw_syn, texts_t[0])
        #get the similarity matrix of kw:product_description
        sim_kw_desc_mean = check_similarity_word_words(kw_syn, texts_t[2])
    
        sim_kw_title_mean_all[kw] = sim_kw_title_mean
        sim_kw_desc_mean_all[kw] = sim_kw_desc_mean
    
    
    sim_title_mean_np = np.array(sim_kw_title_mean_all.values())
    sim_desc_mean_np = np.array(sim_kw_desc_mean_all.values())
    
    sim_title_mean_val = np.mean(sim_title_mean_np)
    sim_desc_mean_val = np.mean(sim_desc_mean_np)
    
    print 'sim means: ', sim_title_mean_val, sim_desc_mean_val
    if mode =='title':
        print 'return: ', sim_title_mean_val
        return sim_title_mean_val
    elif mode == 'desc':
        print 'return: ', sim_desc_mean_val
        return sim_desc_mean_val
    elif mode == 'avg':
        print 'return: ', (sim_title_mean_val + sim_desc_mean_val)/2
        return (sim_title_mean_val + sim_desc_mean_val)/2

# %%
train_merged_sub = train_merged.iloc[0:10, :]
train_merged_sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 0 to 9
# Data columns (total 6 columns):
# id                     10 non-null int64
# product_uid            10 non-null int64
# product_title          10 non-null object
# search_term            10 non-null object
# relevance              10 non-null float64
# product_description    10 non-null object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 560.0+ bytes

# %%
# %timeit train_merged_sub['sim_title'] = train_merged_sub[['id','product_title', 'product_description', 'search_term']].apply(lambda row: find_search_similarity_title_desc(row, 'product_title','search_term', 'product_description', 'title'), axis=1)
# Out:
# row id:  2
# keyword:  angle
# keyword:  bracket
# sime means:  0.625 0.625
# return:  0.625
# row id:  3
# keyword:  l
# keyword:  bracket
# sime means:  0.291666666667 0.291666666667
# return:  0.291666666667
# row id:  9
# keyword:  deck
# sime means:  0.25 1.0
# return:  0.25
# row id:  16
# keyword:  rain
# keyword:  shower
# keyword:  head
# sime means:  0.611111111111 0.666666666667
# return:  0.611111111111
# row id:  17
# keyword:  shower
# keyword:  faucet
# sime means:  1.0 1.0
# return:  1.0
# row id:  18
# keyword:  convection
# keyword:  otr
# sime means:  0.5 0.5
# return:  0.5
# row id:  20
# keyword:  microwave
# keyword:  stove
# sime means:  1.0 1.0
# return:  1.0
# row id:  21
# keyword:  microwave
# sime means:  1.0 1.0
# return:  1.0
# row id:  23
# keyword:  emergency
# keyword:  light
# sime means:  1.0 1.0
# return:  1.0
# row id:  27
# keyword:  mdf
# keyword:  3
# keyword:  4
# sime means:  0.666666666667 0.666666666667
# return:  0.666666666667
# row id:  2
# /Users/zhangxinzhou/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:257: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# keyword:  angle
# keyword:  bracket
# sime means:  0.625 0.625
# return:  0.625
# row id:  3
# keyword:  l
# keyword:  bracket
# sime means:  0.291666666667 0.291666666667
# return:  0.291666666667
# row id:  9
# keyword:  deck
# sime means:  0.25 1.0
# return:  0.25
# row id:  16
# keyword:  rain
# keyword:  shower
# keyword:  head
# sime means:  0.611111111111 0.666666666667
# return:  0.611111111111
# row id:  17
# keyword:  shower
# keyword:  faucet
# sime means:  1.0 1.0
# return:  1.0
# row id:  18
# keyword:  convection
# keyword:  otr
# sime means:  0.5 0.5
# return:  0.5
# row id:  20
# keyword:  microwave
# keyword:  stove
# sime means:  1.0 1.0
# return:  1.0
# row id:  21
# keyword:  microwave
# sime means:  1.0 1.0
# return:  1.0
# row id:  23
# keyword:  emergency
# keyword:  light
# sime means:  1.0 1.0
# return:  1.0
# row id:  27
# keyword:  mdf
# keyword:  3
# keyword:  4
# sime means:  0.666666666667 0.666666666667
# return:  0.666666666667
# row id:  2
# keyword:  angle
# keyword:  bracket
# sime means:  0.625 0.625
# return:  0.625
# row id:  3
# keyword:  l
# keyword:  bracket
# sime means:  0.291666666667 0.291666666667
# return:  0.291666666667
# row id:  9
# keyword:  deck
# sime means:  0.25 1.0
# return:  0.25
# row id:  16
# keyword:  rain
# keyword:  shower
# keyword:  head
# sime means:  0.611111111111 0.666666666667
# return:  0.611111111111
# row id:  17
# keyword:  shower
# keyword:  faucet
# sime means:  1.0 1.0
# return:  1.0
# row id:  18
# keyword:  convection
# keyword:  otr
# sime means:  0.5 0.5
# return:  0.5
# row id:  20
# keyword:  microwave
# keyword:  stove
# sime means:  1.0 1.0
# return:  1.0
# row id:  21
# keyword:  microwave
# sime means:  1.0 1.0
# return:  1.0
# row id:  23
# keyword:  emergency
# keyword:  light
# sime means:  1.0 1.0
# return:  1.0
# row id:  27
# keyword:  mdf
# keyword:  3
# keyword:  4
# sime means:  0.666666666667 0.666666666667
# return:  0.666666666667
# row id:  2
# keyword:  angle
# keyword:  bracket
# sime means:  0.625 0.625
# return:  0.625
# row id:  3
# keyword:  l
# keyword:  bracket
# sime means:  0.291666666667 0.291666666667
# return:  0.291666666667
# row id:  9
# keyword:  deck
# sime means:  0.25 1.0
# return:  0.25
# row id:  16
# keyword:  rain
# keyword:  shower
# keyword:  head
# sime means:  0.611111111111 0.666666666667
# return:  0.611111111111
# row id:  17
# keyword:  shower
# keyword:  faucet
# sime means:  1.0 1.0
# return:  1.0
# row id:  18
# keyword:  convection
# keyword:  otr
# sime means:  0.5 0.5
# return:  0.5
# row id:  20
# keyword:  microwave
# keyword:  stove
# sime means:  1.0 1.0
# return:  1.0
# row id:  21
# keyword:  microwave
# sime means:  1.0 1.0
# return:  1.0
# row id:  23
# keyword:  emergency
# keyword:  light
# sime means:  1.0 1.0
# return:  1.0
# row id:  27
# keyword:  mdf
# keyword:  3
# keyword:  4
# sime means:  0.666666666667 0.666666666667
# return:  0.666666666667
# 1 loop, best of 3: 16 s per loop

# %%
# %timeit train_merged_sub['sim_desc'] = train_merged_sub.apply(lambda row: find_search_similarity_title_desc(row, 'product_title','search_term', 'product_description', 'desc'), axis=1)
# Out:
# row id:  2
# keyword:  angle
# keyword:  bracket
# sime means:  0.625 0.625
# return:  0.625
# row id:  3
# keyword:  l
# keyword:  bracket
# sime means:  0.291666666667 0.291666666667
# return:  0.291666666667
# row id:  9
# keyword:  deck
# sime means:  0.25 1.0
# return:  1.0
# row id:  16
# keyword:  rain
# keyword:  shower
# keyword:  head

# %%
train_merged_sub.tail(20)
# Out:
#            id  product_uid                                      product_title  \
# 69779  209201       196313       Ryobi 0.080 in. Pre-Cut Twisted Trimmer Line
# 55111  166961       166069  Amerimax Home Products 3 in. x 4 in. White Alu...
# 17860   55100       114426  Hampton Bay 1-Light Oil Rubbed Bronze Outdoor ...
# 62237  187656       179892  LIFAN 2500 psi 2.5 GPM AR Axial Cam Pump Heavy...
# 21685   67016       118532  BESSEY H-Style Pipe Clamp Fixture Set for 3/4 ...
# 44953  136647       148812  Wyndham Collection Avara 60 in. Vanity in Espr...
# 73952  221152       206381  Easy Gardener 6 ft. x 50 ft. Saddle Tan Sun Sc...
# 6837    21426       104019  Melamine White Shelf Board (Common: 3/4 in. x ...
# 6294    19766       103571  Philips 4 ft. T12 40-Watt Daylight Deluxe Line...
# 21684   67015       118532  BESSEY H-Style Pipe Clamp Fixture Set for 3/4 ...
# 69394  208118       195428  USE Berrol Double Post Toilet Paper Holder in ...
# 65448  196854       186598  Shaw Subtle Scraped Ranch House Prospect Maple...
# 50177  152369       157413  American Furniture Classics 1 Gun Horizontal K...
# 50196  152418       157442  Blackburn 3/0 Stranded to #4 Stranded Type-BC ...
# 72317  216468       202336  Sea Gull Lighting Denhelm 4-Light Brushed Nick...
# 36901  112847       137161  Commercial Electric 6 in. White Recessed Light...
# 26909   82543       124314            1 in. x 6 in. x 6 ft. Select Pine Board
# 21873   67537       118705  Makita 18-Volt Compact Lithium-Ion Brushless C...
# 2711     8390       101424     Porter-Cable Compressor and Combo Kit (2-Tool)
# 57076  172607       169628  Crown Bolt 1/8 in. x 3 in. Zinc-Plated Mushroo...
#
#                          search_term  relevance  \
# 69779                 pre cut  riser       1.33
# 55111  3x4 aluminum downspout straps       3.00
# 17860                             To       1.67
# 62237                     lifan pump       2.33
# 21685               pipe saver clamp       1.67
# 44953                     aqua glass       2.00
# 73952           roller sun screening       2.33
# 6837                 shelving closet       2.33
# 6294       fluorescent light  ballet       2.00
# 21684          pipe over pipe clamps       3.00
# 69394                      ouse post       2.33
# 65448      noble house wood flooring       2.00
# 50177               locking cabinets       2.33
# 50196             4 to 1 cement base       2.33
# 72317    four light wall/bath melody       2.67
# 36901            electric light cans       2.67
# 26909             select pine primed       2.33
# 21873                      brushless       2.33
# 2711            air compressor combo       3.00
# 57076               bolt toggle loop       2.33
#
#                                      product_description  sim_title  sim_desc
# 69779  For cleaner cuts in thicker grass choose Ryobi...   0.214815  0.160866
# 55111  Amerimax home products downspout clip is one o...   0.107883  0.081214
# 17860  Use the Hampton Bay Wall-Mount 1-Light Oil Rub...   0.000000  0.000000
# 62237  Lifan Power USA is a full line of professional...   0.127199  0.109644
# 21685  They are exceptionally affordable you buy the ...   0.221064  0.177908
# 44953  With 2 doors, 4 drawers, 2 open compartments a...   0.223062  0.168959
# 73952  Keep your cool when temperatures soar with the...   0.223223  0.211576
# 6837   Shelving is a quick, easy, and affordable way ...   0.151045  0.179274
# 6294   The Philips Daylight Deluxe 40-Watt Linear Flu...   0.191699  0.158040
# 21684  They are exceptionally affordable you buy the ...   0.263450  0.204517
# 69394  A perfect blend of traditional and contemporar...   0.190673  0.158872
# 65448  Ranch House Maple brings nature in, beautifull...   0.194989  0.167398
# 50177  Proudly display your prized possession in this...   0.245169  0.196742
# 50196  The Blackburn #3/0 Stranded to #4 Stranded Typ...   0.251823  0.205852
# 72317  Denhelm Collection 4-Light Brushed Nickel Wall...   0.207642  0.179650
# 36901  The Commercial Electric 6 in. White Recessed L...   0.252477  0.200844
# 26909  Provide you with the perfect solution for all ...   0.273377  0.209334
# 21873  Makita is the innovation leader in Brushless M...   0.000000  0.000000
# 2711   The Porter-Cable Compressor and Combo Kit (2-T...   0.203192  0.161891
# 57076  These toggle bolts are anchors for use in holl...   0.256236  0.239349

# %% [markdown]
# multiple linear regression
# SVM
# random forest
#
# vis: scatter matrix
#     confusion matrix
#     roc curve
#     word cloud: https://github.com/shubhabrataroy/Thinkful/blob/master/Curriculum/SetNoteBook.ipynb
