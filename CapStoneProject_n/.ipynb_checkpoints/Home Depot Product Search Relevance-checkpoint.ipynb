# %% [markdown]
# # Importing Libraries and Data

# %%
# %matplotlib inline
import numba

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
from IPython.display import display

from nltk.tokenize import word_tokenize, RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk import FreqDist
from nltk.corpus import wordnet as wn

import string
from scipy import stats
import multiprocessing
# Out:
# /Users/zhangxinzhou/anaconda/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
attributes_raw = pd.read_csv('attributes.csv')
product_desc_raw = pd.read_csv('product_descriptions.csv')
test_raw = pd.read_csv('test.csv')
train_raw = pd.read_csv('train.csv')

# %%
attributes_raw.head(20)
# Out:
#     product_uid                    name  \
# 0      100001.0                Bullet01
# 1      100001.0                Bullet02
# 2      100001.0                Bullet03
# 3      100001.0                Bullet04
# 4      100001.0                Bullet05
# 5      100001.0                Bullet06
# 6      100001.0                Bullet07
# 7      100001.0                   Gauge
# 8      100001.0                Material
# 9      100001.0          MFG Brand Name
# 10     100001.0        Number of Pieces
# 11     100001.0     Product Depth (in.)
# 12     100001.0    Product Height (in.)
# 13     100001.0    Product Weight (lb.)
# 14     100001.0     Product Width (in.)
# 15     100002.0      Application Method
# 16     100002.0   Assembled Depth (in.)
# 17     100002.0  Assembled Height (in.)
# 18     100002.0   Assembled Width (in.)
# 19     100002.0                Bullet01
#
#                                                 value
# 0   Versatile connector for various 90° connection...
# 1   Stronger than angled nailing or screw fastenin...
# 2   Help ensure joints are consistently straight a...
# 3               Dimensions: 3 in. x 3 in. x 1-1/2 in.
# 4                            Made from 12-Gauge steel
# 5           Galvanized for extra corrosion resistance
# 6   Install with 10d common nails or #9 x 1-1/2 in...
# 7                                                  12
# 8                                    Galvanized Steel
# 9                                  Simpson Strong-Tie
# 10                                                  1
# 11                                                1.5
# 12                                                  3
# 13                                               0.26
# 14                                                  3
# 15                                 Brush,Roller,Spray
# 16                                            6.63 in
# 17                                            7.76 in
# 18                                            6.63 in
# 19  Revives wood and composite decks, railings, po...

# %%
attributes_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2044803 entries, 0 to 2044802
# Data columns (total 3 columns):
# product_uid    float64
# name           object
# value          object
# dtypes: float64(1), object(2)
# memory usage: 46.8+ MB

# %%
product_desc_raw.head(20)
# Out:
#     product_uid                                product_description
# 0        100001  Not only do angles make joints stronger, they ...
# 1        100002  BEHR Premium Textured DECKOVER is an innovativ...
# 2        100003  Classic architecture meets contemporary design...
# 3        100004  The Grape Solar 265-Watt Polycrystalline PV So...
# 4        100005  Update your bathroom with the Delta Vero Singl...
# 5        100006  Achieving delicious results is almost effortle...
# 6        100007  The Quantum Adjustable 2-Light LED Black Emerg...
# 7        100008  The Teks #10 x 1-1/2 in. Zinc-Plated Steel Was...
# 8        100009  Get the House of Fara 3/4 in. x 3 in. x 8 ft. ...
# 9        100010  Valley View Industries Metal Stakes (4-Pack) a...
# 10       100011  Recycler 22 in. Personal Pace Variable Speed S...
# 11       100012  The 96 in. wide Caramel Simple Weave Rollup Ba...
# 12       100013  The InSinkErator SinkTop Switch Single Outlet ...
# 13       100014  The Rubbermaid 1-Step Folding Plastic Step Sto...
# 14       100015  Backyard X-Scapes, Inc. uses the finest bamboo...
# 15       100016  Make grilling great with this handsome and fun...
# 16       100017  The MD Building Products 36 in. x 36 in. x 1/5...
# 17       100018  This classic plastic sprinkler head that fits ...
# 18       100019  The House of Fara 8 Linear ft. primed MDF Over...
# 19       100020  These unique LED multi-color sticks are sure t...

# %%
product_desc_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124428 entries, 0 to 124427
# Data columns (total 2 columns):
# product_uid            124428 non-null int64
# product_description    124428 non-null object
# dtypes: int64(1), object(1)
# memory usage: 1.9+ MB

# %%
train_raw.head(20)
# Out:
#     id  product_uid                                      product_title  \
# 0    2       100001                  Simpson Strong-Tie 12-Gauge Angle
# 1    3       100001                  Simpson Strong-Tie 12-Gauge Angle
# 2    9       100002  BEHR Premium Textured DeckOver 1-gal. #SC-141 ...
# 3   16       100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 4   17       100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 5   18       100006  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 6   20       100006  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 7   21       100006  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 8   23       100007  Lithonia Lighting Quantum 2-Light Black LED Em...
# 9   27       100009  House of Fara 3/4 in. x 3 in. x 8 ft. MDF Flut...
# 10  34       100010       Valley View Industries Metal Stakes (4-Pack)
# 11  35       100011  Toro Personal Pace Recycler 22 in. Variable Sp...
# 12  37       100011  Toro Personal Pace Recycler 22 in. Variable Sp...
# 13  38       100011  Toro Personal Pace Recycler 22 in. Variable Sp...
# 14  48       100012  Hampton Bay Caramel Simple Weave Bamboo Rollup...
# 15  51       100013  InSinkErator SinkTop Switch Single Outlet for ...
# 16  65       100016  Sunjoy Calais 8 ft. x 5 ft. x 8 ft. Steel Tile...
# 17  69       100017  MD Building Products 36 in. x 36 in. Cloverlea...
# 18  75       100017  MD Building Products 36 in. x 36 in. Cloverlea...
# 19  81       100017  MD Building Products 36 in. x 36 in. Cloverlea...
#
#                            search_term  relevance
# 0                        angle bracket       3.00
# 1                            l bracket       2.50
# 2                            deck over       3.00
# 3                     rain shower head       2.33
# 4                   shower only faucet       2.67
# 5                       convection otr       3.00
# 6                 microwave over stove       2.67
# 7                           microwaves       3.00
# 8                      emergency light       2.67
# 9                              mdf 3/4       3.00
# 10                        steele stake       2.67
# 11      briggs and stratton lawn mower       3.00
# 12                            gas mowe       3.00
# 13                         honda mower       2.00
# 14  hampton bay chestnut pull up shade       2.67
# 15                            disposer       2.67
# 16                        grill gazebo       3.00
# 17                         door guards       1.00
# 18              metal plate cover gcfi       1.67
# 19                      radiator grate       2.33

# %%
train_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74067 entries, 0 to 74066
# Data columns (total 5 columns):
# id               74067 non-null int64
# product_uid      74067 non-null int64
# product_title    74067 non-null object
# search_term      74067 non-null object
# relevance        74067 non-null float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 2.8+ MB

# %%
test_raw.head(20)
# Out:
#     id  product_uid                                      product_title  \
# 0    1       100001                  Simpson Strong-Tie 12-Gauge Angle
# 1    4       100001                  Simpson Strong-Tie 12-Gauge Angle
# 2    5       100001                  Simpson Strong-Tie 12-Gauge Angle
# 3    6       100001                  Simpson Strong-Tie 12-Gauge Angle
# 4    7       100001                  Simpson Strong-Tie 12-Gauge Angle
# 5    8       100001                  Simpson Strong-Tie 12-Gauge Angle
# 6   10       100003  STERLING Ensemble 33-1/4 in. x 60 in. x 75-1/4...
# 7   11       100003  STERLING Ensemble 33-1/4 in. x 60 in. x 75-1/4...
# 8   12       100003  STERLING Ensemble 33-1/4 in. x 60 in. x 75-1/4...
# 9   13       100004  Grape Solar 265-Watt Polycrystalline Solar Pan...
# 10  14       100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 11  15       100005  Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 12  19       100006  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 13  22       100006  Whirlpool 1.9 cu. ft. Over the Range Convectio...
# 14  24       100008  Teks #10 1-1/2 in. External Hex Flange Hex-Hea...
# 15  25       100009  House of Fara 3/4 in. x 3 in. x 8 ft. MDF Flut...
# 16  26       100009  House of Fara 3/4 in. x 3 in. x 8 ft. MDF Flut...
# 17  28       100010       Valley View Industries Metal Stakes (4-Pack)
# 18  29       100010       Valley View Industries Metal Stakes (4-Pack)
# 19  30       100010       Valley View Industries Metal Stakes (4-Pack)
#
#                        search_term
# 0                90 degree bracket
# 1                 metal l brackets
# 2                 simpson sku able
# 3             simpson strong  ties
# 4        simpson strong tie hcc668
# 5                  wood connectors
# 6              bath and shower kit
# 7                   bath drain kit
# 8             one piece tub shower
# 9                      solar panel
# 10  1 handle shower delta trim kit
# 11     delta ashland shower faucet
# 12                   cooking stove
# 13           microwaves over range
# 14             self tapping screws
# 15               3 1/20door casing
# 16                       door trim
# 17                   anchor stakes
# 18                landscape edging
# 19                     lawn edging

# %% [markdown]
# # Data Wrangling

# %%
train_merged = train_raw.merge(product_desc_raw, on='product_uid', how='left')
train_merged.tail(20)
# Out:
#            id  product_uid                                      product_title  \
# 74047  221413       206601  3M Tekk Protection White Vented Hard Hat with ...
# 74048  221415       206602  Hy-Lite Glass Block Fixed Vinyl Windows Driftw...
# 74049  221416       206603  Westinghouse 3 ft. Oil Rubbed Bronze Beaded Ch...
# 74050  221419       206606  BEHR Premium Plus #ICC-101 Florentine Clay Zer...
# 74051  221420       206607  Home Legend Palace Oak Light 3/4 in. Thick x 3...
# 74052  221422       206609  Whitehaus Collection Isabella Wall-Mounted Bat...
# 74053  221423       206610  Champion Power Equipment 6.5 HP Gas-Powered 3 ...
# 74054  221426       206613                    Everbilt 4 in. White Wall Guard
# 74055  221427       206614  Daltile Villa Valleta Calais Springs 18 in. x ...
# 74056  221432       206619  Home Styles Stone Harbor 51 in. Round 7-Piece ...
# 74057  221434       206621  Crown Bolt M6-32 x 90 mm. Internal Hex Socket ...
# 74058  221443       206627           25 in. Stainless Tip-Out Sink Front Tray
# 74059  221449       206631  Masonite New Haven Three Quarter Oval Lite Pri...
# 74060  221450       206632  Lilly Miller UltraGreen 1 Gal. Vitamin B-1 Pla...
# 74061  221455       206637  Schluter Rondec Stainless Steel 3/8 in. x 1 in...
# 74062  221457       206638  Atlantic Windowpane 576 CD or 192 DVD Blu-Ray ...
# 74063  221458       206639  Philips 40-Watt Halogen R20 Flood Light Bulb (...
# 74064  221463       206641  Schlage Camelot In-Active Aged Bronze Handlese...
# 74065  221471       206648  Plastec 11 in. x 24 in. Rose Garden Wall Decor...
# 74066  221473       206650  LICHTENBERG Pool Blue No. 918 Millennial Ryan ...
#
#                                       search_term  relevance  \
# 74047                        hard hat with mining       1.67
# 74048    replace a broken glass in a vinyl window       2.00
# 74049                 ceiling fan with chain cord       1.00
# 74050                             florentine clay       2.33
# 74051                          trim a home lights       2.00
# 74052                     whitehaus bathroom sinl       2.33
# 74053                        6.5 hp gas generator       2.33
# 74054                      splash guard for  wall       2.00
# 74055                spicewood springs floor tile       1.67
# 74056                        laguna porcelin tile       2.00
# 74057                               m6 screw 90mm       2.67
# 74058                           sink tip-out tray       3.00
# 74059          fiberglass front doors by masonite       3.00
# 74060                          starter fertillzer       2.00
# 74061  rondec stainless steel 3/8 edge protection       3.00
# 74062                              tv riser glass       1.00
# 74063                           r20 halogen light       3.00
# 74064     schlage lock siena half dummy knob with       2.33
# 74065                           zen garden  decor       3.00
# 74066                fine sheer curtain 63 inches       2.33
#
#                                      product_description
# 74047  3M TEKK Protection Vented Pro Ratchet Hard Hat...
# 74048  Excellent privacy and decorative solution for ...
# 74049  This Westinghouse Lighting Oil Rubbed Bronze B...
# 74050  BEHR Premium Plus Zero VOC, Self-Priming Inter...
# 74051  Quarter round is typically placed in front of ...
# 74052  Beautify your bathroom or powder room with a W...
# 74053  The Champion Power Equipment 3 in. semi-trash ...
# 74054  The Everbilt 4 in. Wall Guard helps prevent da...
# 74055  This dal-tile villa valleta calais springs por...
# 74056  Stone Harbor 7-Piece Dining Set includes Large...
# 74057  Crown Bolt's metric socket cap screws are idea...
# 74058  Add a little luxury to otherwise wasted space ...
# 74059  Create an inviting, stylish entryway with the ...
# 74060  Lilly Miller UltraGreen Vitamin B-1 Plant Star...
# 74061  The EV/RO100E is a prefabricated corner for Ro...
# 74062  Atlantic, Inc. 94835722 Uniquely designed for ...
# 74063  Philips Energy Advantage lamps use less energy...
# 74064  The Schlage Camelot In-Active Aged Bronze Hand...
# 74065  The Rose Garden is inspired by the popular ear...
# 74066  No. 918 Millennial Ryan heathered texture semi...

# %%
def remove_non_ascii(s):
    printable = set(string.printable)
    return filter(lambda x: x in printable, s)

# %%
train_merged['product_title'] = train_merged['product_title'].apply(remove_non_ascii)
train_merged['product_description'] = train_merged['product_description'].apply(remove_non_ascii)
train_merged['search_term'] = train_merged['search_term'].apply(remove_non_ascii)

# %%
df = train_merged[train_merged['id']==1060]
print df
# Out:
#        id  product_uid                                      product_title  \
# 323  1060       100179  Paslode 3 in. x 0.120-Gauge 30 Galvanized Ring...
#
#                   search_term  relevance  \
# 323  galvanized framing nails       2.67
#
#                                    product_description
# 323  For exterior applications like framing of sill...

# %%
def tokenize_text(text):
    tokenizer = RegexpTokenizer(r'\w+')
    return tokenizer.tokenize(text)

def remove_stopwords(text):
    stops = stopwords.words('english')
    return [word for word in text if word not in stops]

def get_words_stem(tokenized_text):
    lemmatizer = WordNetLemmatizer()
    return map(lemmatizer.lemmatize, tokenized_text)

# %%
train_merged['product_title'] = train_merged['product_title'].apply(tokenize_text)
train_merged['product_description'] = train_merged['product_description'].apply(tokenize_text)
train_merged['search_term'] = train_merged['search_term'].apply(tokenize_text)

# %%
train_merged.head()
# Out:
#    id  product_uid                                      product_title  \
# 0   2       100001           [Simpson, Strong, Tie, 12, Gauge, Angle]
# 1   3       100001           [Simpson, Strong, Tie, 12, Gauge, Angle]
# 2   9       100002  [BEHR, Premium, Textured, DeckOver, 1, gal, SC...
# 3  16       100005  [Delta, Vero, 1, Handle, Shower, Only, Faucet,...
# 4  17       100005  [Delta, Vero, 1, Handle, Shower, Only, Faucet,...
#
#               search_term  relevance  \
# 0        [angle, bracket]       3.00
# 1            [l, bracket]       2.50
# 2            [deck, over]       3.00
# 3    [rain, shower, head]       2.33
# 4  [shower, only, faucet]       2.67
#
#                                  product_description
# 0  [Not, only, do, angles, make, joints, stronger...
# 1  [Not, only, do, angles, make, joints, stronger...
# 2  [BEHR, Premium, Textured, DECKOVER, is, an, in...
# 3  [Update, your, bathroom, with, the, Delta, Ver...
# 4  [Update, your, bathroom, with, the, Delta, Ver...

# %%
train_merged['product_title'] = train_merged['product_title'].apply(remove_stopwords)
train_merged['product_description'] = train_merged['product_description'].apply(remove_stopwords)
train_merged['search_term'] = train_merged['search_term'].apply(remove_stopwords)

# %%
train_merged.head()
# Out:
#    id  product_uid                                      product_title  \
# 0   2       100001           [Simpson, Strong, Tie, 12, Gauge, Angle]
# 1   3       100001           [Simpson, Strong, Tie, 12, Gauge, Angle]
# 2   9       100002  [BEHR, Premium, Textured, DeckOver, 1, gal, SC...
# 3  16       100005  [Delta, Vero, 1, Handle, Shower, Only, Faucet,...
# 4  17       100005  [Delta, Vero, 1, Handle, Shower, Only, Faucet,...
#
#             search_term  relevance  \
# 0      [angle, bracket]       3.00
# 1          [l, bracket]       2.50
# 2                [deck]       3.00
# 3  [rain, shower, head]       2.33
# 4      [shower, faucet]       2.67
#
#                                  product_description
# 0  [Not, angles, make, joints, stronger, also, pr...
# 1  [Not, angles, make, joints, stronger, also, pr...
# 2  [BEHR, Premium, Textured, DECKOVER, innovative...
# 3  [Update, bathroom, Delta, Vero, Single, Handle...
# 4  [Update, bathroom, Delta, Vero, Single, Handle...

# %%
train_merged['product_title'] = train_merged['product_title'].apply(get_words_stem)
train_merged['product_description'] = train_merged['product_description'].apply(get_words_stem)
train_merged['search_term'] = train_merged['search_term'].apply(get_words_stem)

# %%
train_merged.head()
# Out:
#    id  product_uid                                      product_title  \
# 0   2       100001           [Simpson, Strong, Tie, 12, Gauge, Angle]
# 1   3       100001           [Simpson, Strong, Tie, 12, Gauge, Angle]
# 2   9       100002  [BEHR, Premium, Textured, DeckOver, 1, gal, SC...
# 3  16       100005  [Delta, Vero, 1, Handle, Shower, Only, Faucet,...
# 4  17       100005  [Delta, Vero, 1, Handle, Shower, Only, Faucet,...
#
#             search_term  relevance  \
# 0      [angle, bracket]       3.00
# 1          [l, bracket]       2.50
# 2                [deck]       3.00
# 3  [rain, shower, head]       2.33
# 4      [shower, faucet]       2.67
#
#                                  product_description
# 0  [Not, angle, make, joint, stronger, also, prov...
# 1  [Not, angle, make, joint, stronger, also, prov...
# 2  [BEHR, Premium, Textured, DECKOVER, innovative...
# 3  [Update, bathroom, Delta, Vero, Single, Handle...
# 4  [Update, bathroom, Delta, Vero, Single, Handle...

# %%
train_merged['product_title_len'] = train_merged['product_title'].apply(len)
train_merged['product_description_len'] = train_merged['product_description'].apply(len)
train_merged['search_term_len'] = train_merged['search_term'].apply(len)

# %%
train_merged.head()
# Out:
#    id  product_uid                                      product_title  \
# 0   2       100001           [Simpson, Strong, Tie, 12, Gauge, Angle]
# 1   3       100001           [Simpson, Strong, Tie, 12, Gauge, Angle]
# 2   9       100002  [BEHR, Premium, Textured, DeckOver, 1, gal, SC...
# 3  16       100005  [Delta, Vero, 1, Handle, Shower, Only, Faucet,...
# 4  17       100005  [Delta, Vero, 1, Handle, Shower, Only, Faucet,...
#
#             search_term  relevance  \
# 0      [angle, bracket]       3.00
# 1          [l, bracket]       2.50
# 2                [deck]       3.00
# 3  [rain, shower, head]       2.33
# 4      [shower, faucet]       2.67
#
#                                  product_description  product_title_len  \
# 0  [Not, angle, make, joint, stronger, also, prov...                  6
# 1  [Not, angle, make, joint, stronger, also, prov...                  6
# 2  [BEHR, Premium, Textured, DECKOVER, innovative...                 12
# 3  [Update, bathroom, Delta, Vero, Single, Handle...                 13
# 4  [Update, bathroom, Delta, Vero, Single, Handle...                 13
#
#    product_description_len  search_term_len
# 0                       96                2
# 1                       96                2
# 2                      126                1
# 3                       72                3
# 4                       72                2

# %% [markdown]
# ## try to find the similarity among the search term and the description and product title

# %% [markdown]
# ### experiment on the single row:

# %% [markdown]
# #### extract the text, tokenize the sentences and clean up the text

# %%
from nltk.tokenize import word_tokenize, RegexpTokenizer

# %%
#tokenize and remove punctuation
tokenizer = RegexpTokenizer(r'\w+')
texts_t = [tokenizer.tokenize(t) for t in texts]

# %%
#remove stopwords
from nltk.corpus import stopwords

def remove_stopwords(text):
    return [word for word in text if word not in stopwords.words('english')]
    
texts_t = map(remove_stopwords, texts_t)

# %%
#remove suffix of the words
from nltk.stem.wordnet import WordNetLemmatizer
def get_words_stem(tokenized_text):
    lemmatizer = WordNetLemmatizer()
    return map(lemmatizer.lemmatize, tokenized_text)

texts_t = map(get_words_stem, texts_t)

# %% [markdown]
# #### use freqdist() to check the frequencies of each word and compare it with the search term

# %%
from nltk import FreqDist

# %%
def get_freq_in_text(text, word):
#     print text
    freq = FreqDist(text)
    return freq[word]

# %%
texts_t

# %%
for word in texts_t[1]:
    print word
    print 'freq in title: ', get_freq_in_text(texts_t[0], word)
    print 'freq in desc: ', get_freq_in_text(texts_t[2], word)

# %% [markdown]
# #### use synsets module to check simlilarity

# %% [markdown]
#  ##### method:
# * text_words
#     * word
#     * word
#     * word
#     * word
#         * synset1 <-loop through each synset
#         * synset2
#         * synset3
#
#  compared to:
#     * ref_word
#         * synset1
#         * synset2
#
#  find the max similarity between eg word:synset1 and ref_word:synset2
#
#  append this simliarity into word's syn_sims
#
#  find the max similarity between word:synset2 and the ref_word's synsets
#  ...
#  until each synset in the word has found the max similarity to the ref_word
#
#  then return the max value of the word's syn_sims list to represent the similarity of the word to the ref_word

# %%
kw = texts_t[1][1]
kw

# %%
kw_syn = wn.synsets(kw)
kw_syn

# %%
def compare_synsets(synsets1, synsets2):
    comparisons = [syn1.path_similarity(syn2) for syn2 in synsets2 for syn1 in synsets1]
    comparisons = [v for v in comparisons if v is not None]
    return sum(comparisons)

# %%
def get_synsets(word):
    return wn.synsets(word)

# %%
def check_similarity_word_words(ref_word_synsets, words):
    synsets_of_all_words = [wn.synsets(word) for word in words]
#     print synsets_of_all_words
    sim_word_to_word  = [compare_synsets(ref_word_synsets, synsets) for synsets in synsets_of_all_words]
    return sum(sim_word_to_word)

# %%
print kw, kw_syn, texts_t[0]
sim_kw_title = check_similarity_word_words(kw_syn, texts_t[0])
kw, sim_kw_title

# %% [markdown]
# * check similarity between search key word and the product description

# %%
sim_kw_desc = check_similarity_word_words(kw_syn, texts_t[2])
kw, sim_kw_desc

# %% [markdown]
# * mean values of the similarities

# %%
def cal_similarities_mean(similarities_list):
    sims = [v for k,v in similarities_list.iteritems()]
    #drop na
    sims = np.array([e for e in sims if e != None])
    return sims.mean()

# %%
# sim_kw_title_mean =cal_similarities_mean(sim_kw_title)
# print sim_kw_title_mean

# sim_kw_desc_mean = cal_similarities_mean(sim_kw_desc)
# print sim_kw_desc_mean

# %% [markdown]
# ### run on all rows

# %%
def get_freq_in_text(text, word):
#     print text
    freq = FreqDist(text)
    return freq[word]

def compare_synsets(synsets1, synsets2):
    comparisons = [syn1.path_similarity(syn2) for syn2 in synsets2 for syn1 in synsets1]
    comparisons = [v for v in comparisons if v is not None]
    if len(comparisons) > 0:
        return max(comparisons)
    else:
        return 0

def check_similarity_word_words(ref_word_synsets, words):
    synsets_of_all_words = [wn.synsets(word) for word in words]
#     print synsets_of_all_words
    sim_word_to_word  = [compare_synsets(ref_word_synsets, synsets) for synsets in synsets_of_all_words]
    sim_word_to_word = [v for v in sim_word_to_word if v > 0]
    if len(sim_word_to_word) > 0:
        return np.mean(np.array(sim_word_to_word))
    else:
        return 0

# %%
# core function to find the similarity between the search term and the target text
def find_search_similarity_title_desc(row,title_col_name,search_col_name, desc_col_name, mode):
#     print type(row)
    texts = [row[title_col_name],row[search_col_name],row[desc_col_name] ]
#     print texts
    
    sim_kw_title_mean_all = {}
    sim_kw_desc_mean_all = {}
    
    for kw in texts[1]:
#         print 'keyword: ', kw
        #get the synsets of the keyword
        kw_syn = wn.synsets(kw)
        #get the similarity matrix of kw:product_title
        sim_kw_title_mean = check_similarity_word_words(kw_syn, texts[0])
        #get the similarity matrix of kw:product_description
        sim_kw_desc_mean = check_similarity_word_words(kw_syn, texts[2])
    
        sim_kw_title_mean_all[kw] = sim_kw_title_mean
        sim_kw_desc_mean_all[kw] = sim_kw_desc_mean
    
    
    sim_title_mean_np = np.array(sim_kw_title_mean_all.values())
    sim_desc_mean_np = np.array(sim_kw_desc_mean_all.values())
    
    sim_title_mean_val = np.mean(sim_title_mean_np)
    sim_desc_mean_val = np.mean(sim_desc_mean_np)
    
#     print 'sim means: ', sim_title_mean_val, sim_desc_mean_val
    if mode =='title':
#         print 'row id: ', row.id, ', return: ', sim_title_mean_val
        return sim_title_mean_val
    elif mode == 'desc':
#         print 'row id: ', row.id, ', return: ', sim_desc_mean_val
        return sim_desc_mean_val
    else:
#         print 'row id: ', row.id, ', return: ', (sim_title_mean_val + sim_desc_mean_val)/2
        return (sim_title_mean_val + sim_desc_mean_val)/2

# %%
# wrapper functions so that the pool.map() can call the core function
def find_search_similarity_title(row_number):
    return find_search_similarity_title_desc(train_merged.iloc[row_number, :],'product_title','search_term', 'product_description', 'title')

def find_search_similarity_desc(row_number):
    return find_search_similarity_title_desc(train_merged.iloc[row_number, :],'product_title','search_term', 'product_description', 'desc')

# %%
def find_search_freq_title_desc(row,title_col_name,search_col_name, desc_col_name, mode):
#     print 'row id: ', row.id
    texts = [row[title_col_name],row[search_col_name],row[desc_col_name] ]
    
    if mode == 'title':
        counts = [get_freq_in_text(texts[0], kw) for kw in texts[1]]
#         print counts
        f = sum(counts)
    elif mode == 'desc':
        counts = [get_freq_in_text(texts[2], kw) for kw in texts[1]] 
        f = sum(counts)
    else:
        f = (sum([get_freq_in_text(texts[0], kw) for kw in texts[1]]) + sum([get_freq_in_text(texts[2], kw) for kw in texts[1]]))/2
#     print 'f: ', f
    return f

# %%
train_merged_sub = train_merged.iloc[0:100, :]
train_merged_sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 9 columns):
# id                         100 non-null int64
# product_uid                100 non-null int64
# product_title              100 non-null object
# search_term                100 non-null object
# relevance                  100 non-null float64
# product_description        100 non-null object
# product_title_len          100 non-null int64
# product_description_len    100 non-null int64
# search_term_len            100 non-null int64
# dtypes: float64(1), int64(5), object(3)
# memory usage: 7.8+ KB

# %%
# %timeit train_merged['freq_title_sum'] = train_merged.apply(lambda row: find_search_freq_title_desc(row, 'product_title','search_term', 'product_description', mode='title'), axis=1)
# %timeit train_merged['freq_desc_sum'] = train_merged.apply(lambda row: find_search_freq_title_desc(row, 'product_title','search_term', 'product_description', mode='desc'), axis=1)
# Out:
# 1 loop, best of 3: 10.9 s per loop
# 1 loop, best of 3: 24.7 s per loop

# %%
train_merged.head()
# Out:
#    id  product_uid                                      product_title  \
# 0   2       100001           [Simpson, Strong, Tie, 12, Gauge, Angle]
# 1   3       100001           [Simpson, Strong, Tie, 12, Gauge, Angle]
# 2   9       100002  [BEHR, Premium, Textured, DeckOver, 1, gal, SC...
# 3  16       100005  [Delta, Vero, 1, Handle, Shower, Only, Faucet,...
# 4  17       100005  [Delta, Vero, 1, Handle, Shower, Only, Faucet,...
#
#             search_term  relevance  \
# 0      [angle, bracket]       3.00
# 1          [l, bracket]       2.50
# 2                [deck]       3.00
# 3  [rain, shower, head]       2.33
# 4      [shower, faucet]       2.67
#
#                                  product_description  product_title_len  \
# 0  [Not, angle, make, joint, stronger, also, prov...                  6
# 1  [Not, angle, make, joint, stronger, also, prov...                  6
# 2  [BEHR, Premium, Textured, DECKOVER, innovative...                 12
# 3  [Update, bathroom, Delta, Vero, Single, Handle...                 13
# 4  [Update, bathroom, Delta, Vero, Single, Handle...                 13
#
#    product_description_len  search_term_len  freq_title_sum  freq_desc_sum
# 0                       96                2               0              2
# 1                       96                2               0              0
# 2                      126                1               0              3
# 3                       72                3               0              0
# 4                       72                2               0              0

# %%
# %%time 
print len(train_merged)
if __name__ == '__main__':
    pool = multiprocessing.Pool(processes=16)
    train_merged['sim_title'] = pool.map(find_search_similarity_title, range(0, len(train_merged)))

    pool.close() #we are not adding any more processes
    pool.join() #tell it to wait until all threads are done before going on
# Out:
# 74067
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-32-8ab6d6a9b590> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'time', u'', u"print len(train_merged)\nif __name__ == '__main__':\n    pool = multiprocessing.Pool(processes=16)\n    train_merged['sim_title'] = pool.map(find_search_similarity_title, range(0, len(train_merged)))\n\n    pool.close() #we are not adding any more processes\n    pool.join() #tell it to wait until all threads are done before going on")
#
# /Users/zhangxinzhou/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2118             magic_arg_s = self.var_expand(line, stack_depth)
#    2119             with self.builtin_trap:
# -> 2120                 result = fn(magic_arg_s, cell)
#    2121             return result
#    2122
#
# <decorator-gen-60> in time(self, line, cell, local_ns)
#
# /Users/zhangxinzhou/anaconda/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /Users/zhangxinzhou/anaconda/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#    1175         else:
#    1176             st = clock2()
# -> 1177             exec(code, glob, local_ns)
#    1178             end = clock2()
#    1179             out = None
#
# <timed exec> in <module>()
#
# /Users/zhangxinzhou/anaconda/lib/python2.7/multiprocessing/pool.pyc in map(self, func, iterable, chunksize)
#     249         '''
#     250         assert self._state == RUN
# --> 251         return self.map_async(func, iterable, chunksize).get()
#     252
#     253     def imap(self, func, iterable, chunksize=1):
#
# /Users/zhangxinzhou/anaconda/lib/python2.7/multiprocessing/pool.pyc in get(self, timeout)
#     565             return self._value
#     566         else:
# --> 567             raise self._value
#     568
#     569     def _set(self, i, obj):
#
# IndexError: single positional indexer is out-of-bounds

# %%
train_merged.head()
# Out:
#    id  product_uid                                      product_title  \
# 0   2       100001           [Simpson, Strong, Tie, 12, Gauge, Angle]
# 1   3       100001           [Simpson, Strong, Tie, 12, Gauge, Angle]
# 2   9       100002  [BEHR, Premium, Textured, DeckOver, 1, gal, SC...
# 3  16       100005  [Delta, Vero, 1, Handle, Shower, Only, Faucet,...
# 4  17       100005  [Delta, Vero, 1, Handle, Shower, Only, Faucet,...
#
#             search_term  relevance  \
# 0      [angle, bracket]       3.00
# 1          [l, bracket]       2.50
# 2                [deck]       3.00
# 3  [rain, shower, head]       2.33
# 4      [shower, faucet]       2.67
#
#                                  product_description  product_title_len  \
# 0  [Not, angle, make, joint, stronger, also, prov...                  6
# 1  [Not, angle, make, joint, stronger, also, prov...                  6
# 2  [BEHR, Premium, Textured, DECKOVER, innovative...                 12
# 3  [Update, bathroom, Delta, Vero, Single, Handle...                 13
# 4  [Update, bathroom, Delta, Vero, Single, Handle...                 13
#
#    product_description_len  search_term_len  freq_title_sum  freq_desc_sum  \
# 0                       96                2               0              2
# 1                       96                2               0              0
# 2                      126                1               0              3
# 3                       72                3               0              0
# 4                       72                2               0              0
#
#    sim_title
# 0   0.275694
# 1   0.171313
# 2   0.187879
# 3   0.228968
# 4   0.220725

# %%
# %%time
if __name__ == '__main__':
    pool = multiprocessing.Pool(processes=16)
    train_merged['sim_desc'] = pool.map(find_search_similarity_desc, range(0, len(train_merged)))
    
    pool.close() #we are not adding any more processes
    pool.join() #tell it to wait until all threads are done before going on
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-33-9f6a44f9486e> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'time', u'', u"if __name__ == '__main__':\n    pool = multiprocessing.Pool(processes=16)\n    train_merged['sim_desc'] = pool.map(find_search_similarity_desc, range(0, len(train_merged)))\n    \n    pool.close() #we are not adding any more processes\n    pool.join() #tell it to wait until all threads are done before going on")
#
# /Users/zhangxinzhou/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2118             magic_arg_s = self.var_expand(line, stack_depth)
#    2119             with self.builtin_trap:
# -> 2120                 result = fn(magic_arg_s, cell)
#    2121             return result
#    2122
#
# <decorator-gen-60> in time(self, line, cell, local_ns)
#
# /Users/zhangxinzhou/anaconda/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /Users/zhangxinzhou/anaconda/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#    1175         else:
#    1176             st = clock2()
# -> 1177             exec(code, glob, local_ns)
#    1178             end = clock2()
#    1179             out = None
#
# <timed exec> in <module>()
#
# /Users/zhangxinzhou/anaconda/lib/python2.7/multiprocessing/pool.pyc in map(self, func, iterable, chunksize)
#     249         '''
#     250         assert self._state == RUN
# --> 251         return self.map_async(func, iterable, chunksize).get()
#     252
#     253     def imap(self, func, iterable, chunksize=1):
#
# /Users/zhangxinzhou/anaconda/lib/python2.7/multiprocessing/pool.pyc in get(self, timeout)
#     565             return self._value
#     566         else:
# --> 567             raise self._value
#     568
#     569     def _set(self, i, obj):
#
# IndexError: single positional indexer is out-of-bounds

# %%
train_merged.tail(20)
# Out:
#      id  product_uid                                      product_title  \
# 80  290       100050  [Hampton, Bay, Beverly, Patio, Dining, Arm, Ch...
# 81  293       100051  [Hampton, Bay, Spring, Haven, Brown, All, Weat...
# 82  294       100051  [Hampton, Bay, Spring, Haven, Brown, All, Weat...
# 83  297       100051  [Hampton, Bay, Spring, Haven, Brown, All, Weat...
# 84  305       100053                   [60, x, 150, ft, 10, 10, Remesh]
# 85  314       100054  [Stanley, Doors, 36, x, 80, Chatham, 3, 4, Lit...
# 86  318       100054  [Stanley, Doors, 36, x, 80, Chatham, 3, 4, Lit...
# 87  319       100054  [Stanley, Doors, 36, x, 80, Chatham, 3, 4, Lit...
# 88  323       100055  [MOEN, Essie, Single, Handle, Pull, Down, Spra...
# 89  327       100055  [MOEN, Essie, Single, Handle, Pull, Down, Spra...
# 90  331       100055  [MOEN, Essie, Single, Handle, Pull, Down, Spra...
# 91  334       100055  [MOEN, Essie, Single, Handle, Pull, Down, Spra...
# 92  335       100055  [MOEN, Essie, Single, Handle, Pull, Down, Spra...
# 93  340       100056  [Bare, Ground, 4, Gal, Liquid, De, Icer, Case, 4]
# 94  341       100057  [Owens, Corning, R, 19, Kraft, Faced, Insulati...
# 95  343       100057  [Owens, Corning, R, 19, Kraft, Faced, Insulati...
# 96  346       100057  [Owens, Corning, R, 19, Kraft, Faced, Insulati...
# 97  347       100057  [Owens, Corning, R, 19, Kraft, Faced, Insulati...
# 98  350       100057  [Owens, Corning, R, 19, Kraft, Faced, Insulati...
# 99  351       100058  [Gama, Sonic, 40, LED, Rechargeable, Battery, ...
#
#                               search_term  relevance  \
# 80                      [outdoor, dining]       2.67
# 81               [cushion, outdoorlounge]       3.00
# 82                 [hampton, bay, spring]       3.00
# 83                     [outdoorfurniture]       2.33
# 84                             [wiremesh]       3.00
# 85                          [front, door]       3.00
# 86                 [prehung, steel, door]       3.00
# 87                        [stanley, door]       2.67
# 88      [kingsley, moen, kitchen, faucet]       2.33
# 89                [kitchen, sink, faucet]       3.00
# 90  [pricepfister, kitchen, faucet, g135]       2.00
# 91                      [soap, dispenser]       2.67
# 92             [soap, dispenser, kitchen]       2.00
# 93                         [roof, melter]       1.33
# 94          [6, kraft, faced, insulation]       2.33
# 95               [fiberglass, insulation]       2.33
# 96                  [owen, corning, 7, 3]       2.00
# 97                                [R, 15]       1.33
# 98                      [r19, insulation]       3.00
# 99                     [battery, lantern]       3.00
#
#                                   product_description  product_title_len  \
# 80  [Sit, back, relax, comfort, style, Beverly, Pa...                 11
# 81  [Soak, outdoors, Spring, Haven, Brown, Wicker,...                 14
# 82  [Soak, outdoors, Spring, Haven, Brown, Wicker,...                 14
# 83  [Soak, outdoors, Spring, Haven, Brown, Wicker,...                 14
# 84  [The, 60, x, 150, ft, 10, 10, Remesh, provides...                  7
# 85  [Stanley, Doors, help, create, entrance, exten...                 16
# 86  [Stanley, Doors, help, create, entrance, exten...                 16
# 87  [Stanley, Doors, help, create, entrance, exten...                 16
# 88  [The, Essie, faucet, Spot, Resist, Stainless, ...                 14
# 89  [The, Essie, faucet, Spot, Resist, Stainless, ...                 14
# 90  [The, Essie, faucet, Spot, Resist, Stainless, ...                 14
# 91  [The, Essie, faucet, Spot, Resist, Stainless, ...                 14
# 92  [The, Essie, faucet, Spot, Resist, Stainless, ...                 14
# 93  [Bare, Ground, liquid, deicer, environmentally...                  9
# 94  [EcoTouch, insulation, reinvention, fiberglass...                 11
# 95  [EcoTouch, insulation, reinvention, fiberglass...                 11
# 96  [EcoTouch, insulation, reinvention, fiberglass...                 11
# 97  [EcoTouch, insulation, reinvention, fiberglass...                 11
# 98  [EcoTouch, insulation, reinvention, fiberglass...                 11
# 99  [This, rechargeable, emergency, lamp, must, ev...                  9
#
#     product_description_len  search_term_len  freq_title_sum  freq_desc_sum  \
# 80                      133                2               0              3
# 81                       89                2               0              2
# 82                       89                3               0              0
# 83                       89                1               0              0
# 84                       50                1               0              0
# 85                      171                2               0              5
# 86                      171                3               0              6
# 87                      171                2               0              6
# 88                      111                4               0              3
# 89                      111                3               0              3
# 90                      111                4               0              3
# 91                      111                2               0              3
# 92                      111                3               0              3
# 93                       71                2               0              0
# 94                      143                4               0             17
# 95                      143                2               0             16
# 96                      143                4               0              0
# 97                      143                2               2              2
# 98                      143                2               0             13
# 99                       55                2               0              0
#
#     sim_title  sim_desc
# 80   0.118770  0.587471
# 81   0.114427  0.096461
# 82   0.209326  0.171008
# 83   0.000000  0.000000
# 84   0.000000  0.000000
# 85   0.262252  0.206339
# 86   0.181489  0.143362
# 87   0.225780  0.185724
# 88   0.089404  0.058719
# 89   0.183204  0.147964
# 90   0.089404  0.058719
# 91   0.204359  0.144879
# 92   0.196288  0.131440
# 93   0.175714  0.170255
# 94   0.215918  0.180964
# 95   0.160283  0.201369
# 96   0.174940  0.128864
# 97   0.285998  0.126000
# 98   0.110317  0.126514
# 99   0.306954  0.118623

# %%
train_merged['ratio_title'] = train_merged['freq_title_sum'] / train_merged['product_title_len']
train_merged['ratio_desc'] = train_merged['freq_desc_sum'] / train_merged['product_description_len']
# Out:
# /Users/zhangxinzhou/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/zhangxinzhou/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
train_merged.head()
train_merged.to_csv('train_merged_with_features.csv')
# Out:
#    id  product_uid                                      product_title  \
# 0   2       100001           [Simpson, Strong, Tie, 12, Gauge, Angle]
# 1   3       100001           [Simpson, Strong, Tie, 12, Gauge, Angle]
# 2   9       100002  [BEHR, Premium, Textured, DeckOver, 1, gal, SC...
# 3  16       100005  [Delta, Vero, 1, Handle, Shower, Only, Faucet,...
# 4  17       100005  [Delta, Vero, 1, Handle, Shower, Only, Faucet,...
#
#             search_term  relevance  \
# 0      [angle, bracket]       3.00
# 1          [l, bracket]       2.50
# 2                [deck]       3.00
# 3  [rain, shower, head]       2.33
# 4      [shower, faucet]       2.67
#
#                                  product_description  product_title_len  \
# 0  [Not, angle, make, joint, stronger, also, prov...                  6
# 1  [Not, angle, make, joint, stronger, also, prov...                  6
# 2  [BEHR, Premium, Textured, DECKOVER, innovative...                 12
# 3  [Update, bathroom, Delta, Vero, Single, Handle...                 13
# 4  [Update, bathroom, Delta, Vero, Single, Handle...                 13
#
#    product_description_len  search_term_len  freq_title_sum  freq_desc_sum  \
# 0                       96                2               0              2
# 1                       96                2               0              0
# 2                      126                1               0              3
# 3                       72                3               0              0
# 4                       72                2               0              0
#
#    sim_title  sim_desc  ratio_title  ratio_desc
# 0   0.275694  0.238338          0.0    0.020833
# 1   0.171313  0.177538          0.0    0.000000
# 2   0.187879  0.238787          0.0    0.023810
# 3   0.228968  0.213623          0.0    0.000000
# 4   0.220725  0.150104          0.0    0.000000

# %% [markdown]
# * multiple linear regression
# * SVM
# * random forest
#
# * vis: scatter matrix
#    * confusion matrix
#    * roc curve
#    * word cloud: https://github.com/shubhabrataroy/Thinkful/blob/master/Curriculum/SetNoteBook.ipynb

# %% [markdown]
# ## Data Exploring

# %%
train_merged_f = pd.read_csv('train_merged_with_features.csv')
train_merged_f = train_merged_f.dropna()

# %%
train_merged_f.head()
# Out:
#    Unnamed: 0  id  product_uid  \
# 0           0   2       100001
# 1           1   3       100001
# 2           2   9       100002
# 3           3  16       100005
# 4           4  17       100005
#
#                                        product_title  \
# 0  ['Simpson', 'Strong', 'Tie', '12', 'Gauge', 'A...
# 1  ['Simpson', 'Strong', 'Tie', '12', 'Gauge', 'A...
# 2  ['BEHR', 'Premium', 'Textured', 'DeckOver', '1...
# 3  ['Delta', 'Vero', '1', 'Handle', 'Shower', 'On...
# 4  ['Delta', 'Vero', '1', 'Handle', 'Shower', 'On...
#
#                   search_term  relevance  \
# 0        ['angle', 'bracket']       3.00
# 1            ['l', 'bracket']       2.50
# 2                    ['deck']       3.00
# 3  ['rain', 'shower', 'head']       2.33
# 4        ['shower', 'faucet']       2.67
#
#                                  product_description  product_title_len  \
# 0  ['Not', u'angle', 'make', u'joint', 'stronger'...                  6
# 1  ['Not', u'angle', 'make', u'joint', 'stronger'...                  6
# 2  ['BEHR', 'Premium', 'Textured', 'DECKOVER', 'i...                 12
# 3  ['Update', 'bathroom', 'Delta', 'Vero', 'Singl...                 13
# 4  ['Update', 'bathroom', 'Delta', 'Vero', 'Singl...                 13
#
#    product_description_len  search_term_len  freq_title_sum  freq_desc_sum  \
# 0                       96                2               0              2
# 1                       96                2               0              0
# 2                      126                1               0              3
# 3                       72                3               0              0
# 4                       72                2               0              0
#
#    sim_title  sim_desc  ratio_title  ratio_desc
# 0   0.275694  0.238338          0.0    0.020833
# 1   0.171313  0.177538          0.0    0.000000
# 2   0.187879  0.238787          0.0    0.023810
# 3   0.228968  0.213623          0.0    0.000000
# 4   0.220725  0.150104          0.0    0.000000

# %%
# categorize the relevance value if to use classifier, otherwise should use regression algorithm 
def classify_relevance(relevance_value):
    if 0 < relevance_value <=1:
        return 1
    elif 1 < relevance_value <=2:
        return 2
    elif 2 < relevance_value <=3:
        return 3
    else: 
        return relevance_value
train_merged_f['relevance_class'] = train_merged_f['relevance'].apply(lambda x: classify_relevance(x))

# %%
# normalize feature data
columns_to_normalize = ['relevance','product_title_len','product_description_len', 'search_term_len','freq_title_sum','freq_desc_sum','sim_title','sim_desc','ratio_title','ratio_desc']
train_merged_f[columns_to_normalize] = train_merged_f[columns_to_normalize].apply(lambda column: stats.zscore(column))

# %%
train_merged_f.head()
# Out:
#    Unnamed: 0  id  product_uid  \
# 0           0   2       100001
# 1           1   3       100001
# 2           2   9       100002
# 3           3  16       100005
# 4           4  17       100005
#
#                                        product_title  \
# 0  ['Simpson', 'Strong', 'Tie', '12', 'Gauge', 'A...
# 1  ['Simpson', 'Strong', 'Tie', '12', 'Gauge', 'A...
# 2  ['BEHR', 'Premium', 'Textured', 'DeckOver', '1...
# 3  ['Delta', 'Vero', '1', 'Handle', 'Shower', 'On...
# 4  ['Delta', 'Vero', '1', 'Handle', 'Shower', 'On...
#
#                   search_term  relevance  \
# 0        ['angle', 'bracket']   1.157965
# 1            ['l', 'bracket']   0.221495
# 2                    ['deck']   1.157965
# 3  ['rain', 'shower', 'head']  -0.096904
# 4        ['shower', 'faucet']   0.539895
#
#                                  product_description  product_title_len  \
# 0  ['Not', u'angle', 'make', u'joint', 'stronger'...          -1.372795
# 1  ['Not', u'angle', 'make', u'joint', 'stronger'...          -1.372795
# 2  ['BEHR', 'Premium', 'Textured', 'DECKOVER', 'i...           0.149152
# 3  ['Update', 'bathroom', 'Delta', 'Vero', 'Singl...           0.402810
# 4  ['Update', 'bathroom', 'Delta', 'Vero', 'Singl...           0.402810
#
#    product_description_len  search_term_len  freq_title_sum  freq_desc_sum  \
# 0                -0.096043        -0.896320       -0.320189      -0.343961
# 1                -0.096043        -0.896320       -0.320189      -0.888650
# 2                 0.429643        -1.708552       -0.320189      -0.071616
# 3                -0.516591        -0.084089       -0.320189      -0.888650
# 4                -0.516591        -0.896320       -0.320189      -0.888650
#
#    sim_title  sim_desc  ratio_title  ratio_desc  relevance_class
# 0   0.660015  0.797880     -0.33516   -0.389177                3
# 1  -0.380497  0.105459     -0.33516   -0.962296                3
# 2  -0.215364  0.802991     -0.33516   -0.307303                3
# 3   0.194231  0.516415     -0.33516   -0.962296                3
# 4   0.112060 -0.206974     -0.33516   -0.962296                3

# %%
train_merged_f.describe()
# Out:
#          Unnamed: 0             id    product_uid     relevance  \
# count  74057.000000   74057.000000   74057.000000  7.405700e+04
# mean   37035.037269  112391.787799  142334.929770  1.156902e-14
# std    21381.716094   64017.356614   30771.362605  1.000007e+00
# min        0.000000       2.000000  100001.000000 -2.587913e+00
# 25%    18520.000000   57169.000000  115130.000000 -7.149742e-01
# 50%    37036.000000  113234.000000  137338.000000 -9.690436e-02
# 75%    55552.000000  168285.000000  166886.000000  1.157965e+00
# max    74066.000000  221473.000000  206650.000000  1.157965e+00
#
#        product_title_len  product_description_len  search_term_len  \
# count       7.405700e+04             7.405700e+04     7.405700e+04
# mean        1.579891e-15            -4.797344e-16    -1.089967e-13
# std         1.000007e+00             1.000007e+00     1.000007e+00
# min        -2.641084e+00            -1.462824e+00    -1.708552e+00
# 25%        -6.118211e-01            -7.093419e-01    -8.963203e-01
# 50%        -1.045054e-01            -2.537481e-01    -8.408898e-02
# 75%         6.564681e-01             4.296425e-01     7.281423e-01
# max         5.729625e+00             1.429021e+01     9.662687e+00
#
#        freq_title_sum  freq_desc_sum     sim_title      sim_desc  \
# count    7.405700e+04   7.405700e+04  7.405700e+04  7.405700e+04
# mean    -1.788249e-14   4.009846e-16  1.219889e-15 -7.960289e-16
# std      1.000007e+00   1.000007e+00  1.000007e+00  1.000007e+00
# min     -3.201893e-01  -8.886503e-01 -2.088209e+00 -1.916418e+00
# 25%     -3.201893e-01  -6.163055e-01 -5.480933e-01 -5.219186e-01
# 50%     -3.201893e-01  -3.439606e-01 -6.506532e-02 -7.411157e-02
# 75%     -3.201893e-01   4.730741e-01  4.175482e-01  3.724037e-01
# max      2.169268e+01   2.226066e+01  7.880158e+00  9.472004e+00
#
#         ratio_title    ratio_desc  relevance_class
# count  7.405700e+04  7.405700e+04     74057.000000
# mean   9.898364e-15 -8.058035e-15         2.652524
# std    1.000007e+00  1.000007e+00         0.532479
# min   -3.351599e-01 -9.622960e-01         1.000000
# 25%   -3.351599e-01 -7.738735e-01         2.000000
# 50%   -3.351599e-01 -2.477585e-01         3.000000
# 75%   -3.351599e-01  4.606192e-01         3.000000
# max    1.847655e+01  1.416804e+01         3.000000

# %%
from pandas.tools.plotting import scatter_matrix

# %%
scatter = scatter_matrix(train_merged_f, figsize=(20,20))

# %%
feature_columns = ['product_title_len', 'product_description_len', 'search_term_len', 'freq_title_sum', 'freq_desc_sum','sim_title','sim_desc','ratio_title','ratio_desc']

# %%
def explore1D(df, columns):
    for c in columns:
        df[c].value_counts().plot(kind='bar', title=c)
        plt.show()

# %%
explore1D(train_merged_f, ['relevance','relevance_class', 'product_title_len', 'product_description_len', 'search_term_len', 'freq_title_sum', 'freq_desc_sum'])

# %%
def explore_relevance_class_2D(dimension):
    plt.hist(train_merged_f[dimension][train_merged_f['relevance_class']==3], alpha=.3)
    plt.hist(train_merged_f[dimension][train_merged_f['relevance_class']==2], alpha=.3)
    plt.hist(train_merged_f[dimension][train_merged_f['relevance_class']==1], alpha=.3)
    plt.xlabel(dimension)
    plt.ylabel('freq')
    plt.title(dimension + ' frequencies')
    plt.legend(('class3','class2','class1'))
    plt.show()

# %%
for feature in feature_columns:
    explore_relevance_class_2D(feature)

# %%
train_merged_f.corr()
# Out:
#                          Unnamed: 0        id  product_uid  relevance  \
# Unnamed: 0                 1.000000  0.999938     0.988454  -0.117630
# id                         0.999938  1.000000     0.986738  -0.116622
# product_uid                0.988454  0.986738     1.000000  -0.130852
# relevance                 -0.117630 -0.116622    -0.130852   1.000000
# product_title_len          0.044329  0.043982     0.049022  -0.017532
# product_description_len   -0.076303 -0.076609    -0.070966   0.045381
# search_term_len            0.186990  0.186103     0.197601  -0.058809
# freq_title_sum             0.027200  0.027415     0.023725   0.009345
# freq_desc_sum             -0.001298 -0.001193    -0.002611   0.112731
# sim_title                  0.009321  0.010024    -0.000746   0.154874
# sim_desc                  -0.032320 -0.031921    -0.037553   0.089961
# ratio_title                0.023974  0.024217     0.020046   0.018124
# ratio_desc                 0.044603  0.044919     0.039788   0.101738
# relevance_class           -0.084875 -0.084104    -0.095044   0.868520
#
#                          product_title_len  product_description_len  \
# Unnamed: 0                        0.044329                -0.076303
# id                                0.043982                -0.076609
# product_uid                       0.049022                -0.070966
# relevance                        -0.017532                 0.045381
# product_title_len                 1.000000                 0.295697
# product_description_len           0.295697                 1.000000
# search_term_len                   0.152640                 0.058451
# freq_title_sum                    0.137152                -0.006000
# freq_desc_sum                     0.114134                 0.335819
# sim_title                        -0.125371                -0.080160
# sim_desc                         -0.027550                -0.044480
# ratio_title                       0.039363                -0.030798
# ratio_desc                       -0.039368                -0.138286
# relevance_class                  -0.003230                 0.040095
#
#                          search_term_len  freq_title_sum  freq_desc_sum  \
# Unnamed: 0                      0.186990        0.027200      -0.001298
# id                              0.186103        0.027415      -0.001193
# product_uid                     0.197601        0.023725      -0.002611
# relevance                      -0.058809        0.009345       0.112731
# product_title_len               0.152640        0.137152       0.114134
# product_description_len         0.058451       -0.006000       0.335819
# search_term_len                 1.000000        0.379558       0.345916
# freq_title_sum                  0.379558        1.000000       0.181883
# freq_desc_sum                   0.345916        0.181883       1.000000
# sim_title                       0.068075        0.094393       0.171545
# sim_desc                        0.073341       -0.028094       0.245008
# ratio_title                     0.363582        0.945386       0.166550
# ratio_desc                      0.339008        0.214127       0.760642
# relevance_class                -0.023314        0.011779       0.105376
#
#                          sim_title  sim_desc  ratio_title  ratio_desc  \
# Unnamed: 0                0.009321 -0.032320     0.023974    0.044603
# id                        0.010024 -0.031921     0.024217    0.044919
# product_uid              -0.000746 -0.037553     0.020046    0.039788
# relevance                 0.154874  0.089961     0.018124    0.101738
# product_title_len        -0.125371 -0.027550     0.039363   -0.039368
# product_description_len  -0.080160 -0.044480    -0.030798   -0.138286
# search_term_len           0.068075  0.073341     0.363582    0.339008
# freq_title_sum            0.094393 -0.028094     0.945386    0.214127
# freq_desc_sum             0.171545  0.245008     0.166550    0.760642
# sim_title                 1.000000  0.741731     0.112986    0.228161
# sim_desc                  0.741731  1.000000    -0.022777    0.291850
# ratio_title               0.112986 -0.022777     1.000000    0.219845
# ratio_desc                0.228161  0.291850     0.219845    1.000000
# relevance_class           0.125563  0.075399     0.017343    0.095864
#
#                          relevance_class
# Unnamed: 0                     -0.084875
# id                             -0.084104
# product_uid                    -0.095044
# relevance                       0.868520
# product_title_len              -0.003230
# product_description_len         0.040095
# search_term_len                -0.023314
# freq_title_sum                  0.011779
# freq_desc_sum                   0.105376
# sim_title                       0.125563
# sim_desc                        0.075399
# ratio_title                     0.017343
# ratio_desc                      0.095864
# relevance_class                 1.000000

# %% [markdown]
# ### Apply machine learning algorithms

# %%
train_subtrain = train_merged_f.sample(frac=.6)
train_subtest = train_merged_f.sample(frac=.4)

# %% [markdown]
# #### Random Forests Analysis

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier(n_jobs=6)
y, _ = pd.factorize(train_subtrain['relevance_class'])
clf.fit(train_subtrain[feature_columns], y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=6,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
importances = clf.feature_importances_
importances_d = zip(feature_columns, importances)

# %%
importances_d
# Out:
# [('product_title_len', 0.12279907727253206),
#  ('product_description_len', 0.1870395420394691),
#  ('search_term_len', 0.045671148589737101),
#  ('freq_title_sum', 0.013145861661239478),
#  ('freq_desc_sum', 0.039619491276628373),
#  ('sim_title', 0.22908503980922493),
#  ('sim_desc', 0.21584473585651748),
#  ('ratio_title', 0.02527513616155052),
#  ('ratio_desc', 0.12151996733310107)]

# %% [markdown]
# #### SVM

# %%
from sklearn import svm, grid_search

# %% [markdown]
# When 'relevance_class' is the target:
#
# 1. Build the model by usig the grid_search to find the best parameter combination
#
# 1. Test the model on a test subset

# %%
parameters = {'kernel':['linear'], 'C':[1]}
svc = svm.SVC()
clf = grid_search.GridSearchCV(estimator=svc, param_grid=parameters, n_jobs=-1, scoring='accuracy')
X = train_subtrain[feature_columns].values
y = train_subtrain['relevance_class'].values
clf.fit(X, y)
# Out:
# /Users/zhangxinzhou/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /Users/zhangxinzhou/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /Users/zhangxinzhou/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# GridSearchCV(cv=None, error_score='raise',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'kernel': ['linear'], 'C': [1]},
#        pre_dispatch='2*n_jobs', refit=True, scoring='accuracy', verbose=0)

# %%
print 'grid scores: ', clf.grid_scores_
print 'best estimator: ', clf.best_estimator_
print 'best score: ', clf.best_score_
print 'best params: ', clf.best_params_
print 'scorer: ', clf.scorer_
# Out:
# grid scores:  [mean: 0.68078, std: 0.00003, params: {'kernel': 'linear', 'C': 1}]
# best estimator:  SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# best score:  0.680784984471
# best params:  {'kernel': 'linear', 'C': 1}
# scorer:  make_scorer(accuracy_score)

# %%
test_score = clf.score(train_subtest[feature_columns], train_subtest['relevance_class'])
print test_score
# Out:
# /Users/zhangxinzhou/anaconda/lib/python2.7/site-packages/sklearn/grid_search.py:418: ChangedBehaviorWarning: The long-standing behavior to use the estimator's score function in GridSearchCV.score has changed. The scoring parameter is now used.
#   ChangedBehaviorWarning)
# 0.682881544746

# %%
predict_result = clf.predict(train_subtest[feature_columns])

# %%
print len(predict_result)
# Out:
# 29623

# %%
print len(train_subtest['relevance_class'].tolist())
# Out:
# 29623

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(predict_result, train_subtest['relevance_class'].tolist())
fig, ax = plt.subplots()
im = ax.matshow(cm)
for (i, j), z in np.ndenumerate(cm):
    ax.text(j, i, '{:0.1f}'.format(z), ha='center', va='center',
            bbox=dict(boxstyle='round', facecolor='white', edgecolor='0.3'))
    
plt.title('Confusion matrix')
fig.colorbar(im)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %% [markdown]
# When 'relevance' is the target
#    1. Build the model
#    2. Test the model

# %%
parameters = {'kernel':['rbf'], 'C':[1], 'epsilon':[.1]}
svr = svm.SVR()
clf = grid_search.GridSearchCV(estimator=svr, param_grid=parameters, n_jobs=-1, scoring='r2')
X = train_subtrain[feature_columns].values
y = train_subtrain['relevance'].values
clf.fit(X, y)
# Out:
# /Users/zhangxinzhou/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /Users/zhangxinzhou/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# /Users/zhangxinzhou/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/hashing.py:197: DeprecationWarning: Changing the shape of non-C contiguous array by
# descriptor assignment is deprecated. To maintain
# the Fortran contiguity of a multidimensional Fortran
# array, use 'a.T.view(...).T' instead
#   obj_bytes_view = obj.view(self.np.uint8)
# GridSearchCV(cv=None, error_score='raise',
#        estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'kernel': ['rbf'], 'C': [1], 'epsilon': [0.1]},
#        pre_dispatch='2*n_jobs', refit=True, scoring='r2', verbose=0)

# %%
print 'grid scores: ', clf.grid_scores_
print 'best estimator: ', clf.best_estimator_
print 'best score: ', clf.best_score_
print 'best params: ', clf.best_params_
print 'scorer: ', clf.scorer_
# Out:
# grid scores:  [mean: 0.06344, std: 0.00529, params: {'epsilon': 0.1, 'C': 1, 'kernel': 'rbf'}]
# best estimator:  SVR(C=1, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='auto',
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)
# best score:  0.063441743736
# best params:  {'epsilon': 0.1, 'C': 1, 'kernel': 'rbf'}
# scorer:  make_scorer(r2_score)

# %%
#from the viz above we see the data is highly screwed towards class:3, 
#need to bin the sample data better so that the samples are better distributed, 
#with which the accuracy test will make more sense

#http://stackoverflow.com/questions/6163334/binning-data-in-python-with-scipy-numpy
