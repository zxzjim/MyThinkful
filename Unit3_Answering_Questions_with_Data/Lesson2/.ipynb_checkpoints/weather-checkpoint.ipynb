# %%
# %matplotlib inline
import requests
import collections
import datetime
import time
from pandas.io.json import json_normalize
import pandas as pd
import sqlite3 as lite
from dateutil.parser import parse
import matplotlib.pyplot as plt

# %%
cities_and_pos = collections.defaultdict()
cities_and_pos = { "Atlanta": '33.762909,-84.422675',
            "Austin": '30.303936,-97.754355',
            "Boston": '42.331960,-71.020173',
            "Chicago": '41.837551,-87.681844',
            "Cleveland": '41.478462,-81.679435'
        }
print cities_and_pos
# Out:
# {'Boston': '42.331960,-71.020173', 'Atlanta': '33.762909,-84.422675', 'Cleveland': '41.478462,-81.679435', 'Austin': '30.303936,-97.754355', 'Chicago': '41.837551,-87.681844'}

# %%
'''print datetime.datetime.now()
now = datetime.datetime.now()
now_str = now.strftime('%Y-%m-%dT%H:%M:%S')
month_ago = now - datetime.timedelta(days=30)
month_ago_str = month_ago.strftime('%Y-%m-%dT%H:%M:%S')
print "https://api.forecast.io/forecast/1eb174d457808f327bd58e03b98e5c18/%s" % (cities_and_pos['Chicago'] + ',' + now_str)
print "https://api.forecast.io/forecast/1eb174d457808f327bd58e03b98e5c18/%s" % (cities_and_pos['Chicago'] + ',' + month_ago_str)
r = requests.get("https://api.forecast.io/forecast/1eb174d457808f327bd58e03b98e5c18/%s" % (cities_and_pos['Chicago'] + ',' + now_str))
print r
print r.json()['daily']['data'][0]['temperatureMax']
#print city_weather_df.head()
city_max_temp = r.json()['daily']['data'][0]['temperatureMax']
print city_max_temp'''
# Out:
# 2016-01-11 23:14:02.104354
# https://api.forecast.io/forecast/1eb174d457808f327bd58e03b98e5c18/41.837551,-87.681844,2016-01-11T23:14:02
# https://api.forecast.io/forecast/1eb174d457808f327bd58e03b98e5c18/41.837551,-87.681844,2015-12-12T23:14:02
# <Response [200]>
# 27.12
# 0    27.12
# Name: temperatureMax, dtype: float64

# %%
daily_max_temp_dict = collections.defaultdict()
city_max_temp_dict = collections.defaultdict()
for d in range(0,31):
    start_date = datetime.datetime.now() - datetime.timedelta(days=d)
    start_date_str = start_date.strftime('%Y-%m-%dT12:00:00')
    print start_date_str
    for city, pos in cities_and_pos.items():
        print "https://api.forecast.io/forecast/1eb174d457808f327bd58e03b98e5c18/%s" % (cities_and_pos[city] + ',' + start_date_str)
        r = requests.get("https://api.forecast.io/forecast/1eb174d457808f327bd58e03b98e5c18/%s" % (cities_and_pos[city] + ',' + start_date_str))
        if 'daily' in r.json():
            if 'temperatureMax' in r.json()['daily']['data'][0]:
                city_max_temp = r.json()['daily']['data'][0]['temperatureMax']
                print city_max_temp
                city_max_temp_dict[city] = city_max_temp
            else:
                city_max_temp_dict[city] = None
    daily_max_temp_dict[start_date_str] = city_max_temp_dict
    city_max_temp_dict = collections.defaultdict()
# Out:
# 2016-01-13T12:00:00
# https://api.forecast.io/forecast/1eb174d457808f327bd58e03b98e5c18/42.331960,-71.020173,2016-01-13T12:00:00
# 32.38
# https://api.forecast.io/forecast/1eb174d457808f327bd58e03b98e5c18/33.762909,-84.422675,2016-01-13T12:00:00
# 49.16
# https://api.forecast.io/forecast/1eb174d457808f327bd58e03b98e5c18/41.478462,-81.679435,2016-01-13T12:00:00
# 23.94
# https://api.forecast.io/forecast/1eb174d457808f327bd58e03b98e5c18/30.303936,-97.754355,2016-01-13T12:00:00
# 65.44
# https://api.forecast.io/forecast/1eb174d457808f327bd58e03b98e5c18/41.837551,-87.681844,2016-01-13T12:00:00
# 26.69
# 2016-01-12T12:00:00
# https://api.forecast.io/forecast/1eb174d457808f327bd58e03b98e5c18/42.331960,-71.020173,2016-01-12T12:00:00
# 36.49
# https://api.forecast.io/forecast/1eb174d457808f327bd58e03b98e5c18/33.762909,-84.422675,2016-01-12T12:00:00
# 50.92
# https://api.forecast.io/forecast/1eb174d457808f327bd58e03b98e5c18/41.478462,-81.679435,2016-01-12T12:00:00
# 27.82
# https://api.forecast.io/forecast/1eb174d457808f327bd58e03b98e5c18/30.303936,-97.754355,2016-01-12T12:00:00
# 64.33
# https://api.forecast.io/forecast/1eb174d457808f327bd58e03b98e5c18/41.837551,-87.681844,2016-01-12T12:00:00
# 21.31
# 2016-01-11T12:00:00
# https://api.forecast.io/forecast/1eb174d457808f327bd58e03b98e5c18/42.331960,-71.020173,2016-01-11T12:00:00
# 48.96
# https://api.forecast.io/forecast/1eb174d457808f327bd58e03b98e5c18/33.762909,-84.422675,2016-01-11T12:00:00
# 42.47
# https://api.forecast.io/forecast/1eb174d457808f327bd58e03b98e5c18/41.478462,-81.679435,2016-01-11T12:00:00
# 20.17
# https://api.forecast.io/forecast/1eb174d457808f327bd58e03b98e5c18/30.303936,-97.754355,2016-01-11T12:00:00
# 54.24
# https://api.forecast.io/forecast/1eb174d457808f327bd58e03b98e5c18/41.837551,-87.681844,2016-01-11T12:00:00
# 24.7
# 2016-01-10T12:00:00
# https://api.forecast.io/forecast/1eb174d457808f327bd58e03b98e5c18/42.331960,-71.020173,2016-01-10T12:00:00
# 56.18
# https://api.forecast.io/forecast/1eb174d457808f327bd58e03b98e5c18/33.762909,-84.422675,2016-01-10T12:00:00
# 50.85
# https://api.forecast.io/forecast/1eb174d457808f327bd58e03b98e5c18/41.478462,-81.679435,2016-01-10T12:00:00
# 45.59
# https://api.forecast.io/forecast/1eb174d457808f327bd58e03b98e5c18/30.303936,-97.754355,2016-01-10T12:00:00
# 47.51
# https://api.forecast.io/forecast/1eb174d457808f327bd58e03b98e5c18/41.837551,-87.681844,2016-01-10T12:00:00
# 26.17
# 2016-01-09T12:00:00
# https://api.forecast.io/forecast/1eb174d457808f327bd58e03b98e5c18/42.331960,-71.020173,2016-01-09T12:00:00
# 40.16
# https://api.forecast.io/forecast/1eb174d457808f327bd58e03b98e5c18/33.762909,-84.422675,2016-01
# 1451646000 Atlanta 46.56
# 1451646000 Chicago 29.66
# 1451646000 Austin 47.35
# 1451646000 Cleveland 31.22
# 2016-01-08T12:00:00
# 1452250800 Boston 40.4
# 1452250800 Atlanta 53.33
# 1452250800 Chicago 42.27
# 1452250800 Austin 66.39
# 1452250800 Cleveland 43.79
# 2016-01-10T12:00:00
# 1452423600 Boston 56.18
# 1452423600 Atlanta 50.85
# 1452423600 Chicago 26.17
# 1452423600 Austin 47.51
# 1452423600 Cleveland 45.59
# 2015-12-15T12:00:00
# 1450177200 Boston 60.52
# 1450177200 Atlanta 71.61
# 1450177200 Chicago 43.34
# 1450177200 Austin 74.01
# 1450177200 Cleveland 48.82
# 2016-01-02T12:00:00
# 1451732400 Boston 36.71
# 1451732400 Atlanta 46.6
# 1451732400 Chicago 31.06
# 1451732400 Austin 46.09
# 1451732400 Cleveland 32.58
# 2016-01-13T12:00:00
# 1452682800 Boston 32.38
# 1452682800 Atlanta 49.16
# 1452682800 Chicago 26.69
# 1452682800 Austin 65.44
# 1452682800 Cleveland 23.94
# 2016-01-05T12:00:00
# 1451991600 Boston 23.44
# 1451991600 Atlanta 42.48
# 1451991600 Chicago 32.42
# 1451991600 Austin 54.24
# 1451991600 Cleveland 27.29
# 2015-12-22T12:00:00
# 1450782000 Boston 59.05
# 1450782000 Atlanta 62.78
# 1450782000 Chicago 43.03
# 1450782000 Austin 77.87
# 1450782000 Cleveland 54.88
# 2015-12-16T12:00:00
# 1450263600 Boston 47.9
# 1450263600 Atlanta 71.96
# 1450263600 Chicago 53.18
# 1450263600 Austin 63.25
# 1450263600 Cleveland 57.78
# 2015-12-14T12:00:00
# 1450090800 Boston 55.31
# 1450090800 Atlanta 67.66
# 1450090800 Chicago 61.38
# 1450090800 Austin 74.73
# 1450090800 Cleveland 64.48
# 2015-12-23T12:00:00
# 1450868400 Boston 54.76
# 1450868400 Atlanta 64.45
# 1450868400 Chicago 59.29
# 1450868400 Austin 79.99
# 1450868400 Cleveland 65.56

# %%
conn = lite.connect('weather.db')
cur = conn.cursor()
cur.execute('drop table if exists daily_maxtemps;')
create_sql = 'create table daily_maxtemps (day INT PRIMARY KEY, '+', '.join(x + ' REAL' for x in cities_and_pos.iterkeys())+')'
cur.execute(create_sql)

for t, ct in daily_max_temp_dict.iteritems():
    insert_sql = 'INSERT INTO daily_maxtemps(day) VALUES(%s)' % (parse(t).strftime('%s'))
    print insert_sql
    cur.execute(insert_sql)
    for city, temp in ct.iteritems():
        update_sql = 'UPDATE daily_maxtemps SET '+ city +' = ' + str(temp) + ' WHERE day = ' + parse(t).strftime('%s')
        print update_sql
        cur.execute('UPDATE daily_maxtemps SET '+ city +' = ' + str(temp) + ' WHERE day = ' + parse(t).strftime('%s'))
# Out:
# INSERT INTO daily_maxtemps(day) VALUES(1452164400)
# UPDATE daily_maxtemps SET Boston = 39.1 WHERE day = 1452164400
# UPDATE daily_maxtemps SET Atlanta = 58.15 WHERE day = 1452164400
# UPDATE daily_maxtemps SET Chicago = 40.43 WHERE day = 1452164400
# UPDATE daily_maxtemps SET Austin = 69.71 WHERE day = 1452164400
# UPDATE daily_maxtemps SET Cleveland = 42.86 WHERE day = 1452164400
# INSERT INTO daily_maxtemps(day) VALUES(1451386800)
# UPDATE daily_maxtemps SET Boston = 39.43 WHERE day = 1451386800
# UPDATE daily_maxtemps SET Atlanta = 69.66 WHERE day = 1451386800
# UPDATE daily_maxtemps SET Chicago = 41.25 WHERE day = 1451386800
# UPDATE daily_maxtemps SET Austin = 48.68 WHERE day = 1451386800
# UPDATE daily_maxtemps SET Cleveland = 50.46 WHERE day = 1451386800
# INSERT INTO daily_maxtemps(day) VALUES(1451127600)
# UPDATE daily_maxtemps SET Boston = 55.18 WHERE day = 1451127600
# UPDATE daily_maxtemps SET Atlanta = 76.41 WHERE day = 1451127600
# UPDATE daily_maxtemps SET Chicago = 44.32 WHERE day = 1451127600
# UPDATE daily_maxtemps SET Austin = 76.76 WHERE day = 1451127600
# UPDATE daily_maxtemps SET Cleveland = 54.8 WHERE day = 1451127600
# INSERT INTO daily_maxtemps(day) VALUES(1452596400)
# UPDATE daily_maxtemps SET Boston = 36.49 WHERE day = 1452596400
# UPDATE daily_maxtemps SET Atlanta = 50.92 WHERE day = 1452596400
# UPDATE daily_maxtemps SET Chicago = 21.31 WHERE day = 1452596400
# UPDATE daily_maxtemps SET Austin = 64.33 WHERE day = 1452596400
# UPDATE daily_maxtemps SET Cleveland = 27.82 WHERE day = 1452596400
# INSERT INTO daily_maxtemps(day) VALUES(1452078000)
# UPDATE daily_maxtemps SET Boston = 39.37 WHERE day = 1452078000
# UPDATE daily_maxtemps SET Atlanta = 44.09 WHERE day = 1452078000
# UPDATE daily_maxtemps SET Chicago = 35.74 WHERE day = 1452078000
# UPDATE daily_maxtemps SET Austin = 51.61 WHERE day = 1452078000
# UPDATE daily_maxtemps SET Cleveland = 36.76 WHERE day = 1452078000
# INSERT INTO daily_maxtemps(day) VALUES(1451214000)
# UPDATE daily_maxtemps SET Boston = 49.79 WHERE day = 1451214000
# UPDATE daily_maxtemps SET Atlanta = 74.74 WHERE day = 1451214000
# UPDATE daily_maxtemps SET Chicago = 42.28 WHERE day = 1451214000
# UPDATE daily_maxtemps SET Austin = 73.11 WHERE day = 1451214000
# UPDATE daily_maxtemps SET Cleveland = 59.96 WHERE day = 1451214000
# INSERT INTO daily_maxtemps(day) VALUES(1451818800)
# UPDATE daily_maxtemps SET Boston = 41.53 WHERE day = 1451818800
# UPDATE daily_maxtemps SET Atlanta = 51.32 WHERE day = 1451818800
# UPDATE daily_maxtemps SET Chicago = 30.2 WHERE day = 1451818800
# UPDATE daily_maxtemps SET Austin = 59.09 WHERE day = 1451818800
# UPDATE daily_maxtemps SET Cleveland = 33.73 WHERE day = 1451818800
# INSERT INTO daily_maxtemps(day) VALUES(1450609200)
# UPDATE daily_maxtemps SET Boston = 40.69 WHERE day = 1450609200
# UPDATE daily_maxtemps SET Atlanta = 54.19 WHERE day = 1450609200
# UPDATE daily_maxtemps SET Chicago = 50.01 WHERE day = 1450609200
# UPDATE daily_maxtemps SET Austin = 66.84 WHERE day = 1450609200
# UPDATE daily_maxtemps SET Cleveland = 43.62 WHERE day = 1450609200
# INSERT INTO daily_maxtemps(day) VALUES(1450350000)
# UPDATE daily_maxtemps SET Boston = 51.83 WHERE day = 1450350000
# UPDATE daily_maxtemps SET Atlanta = 64.26 WHERE day = 1450350000
# UPDATE daily_maxtemps SET Chicago = 35.8 WHERE day = 1450350000
# UPDATE daily_maxtemps SET Austin = 66.46 WHERE day = 1450350000
# UPDATE daily_maxtemps SET Cleveland = 60.03 WHERE day = 1450350000
# INSERT INTO daily_maxtemps(day) VALUES(1451300400)
# UPDATE daily_maxtemps SET Boston = 37.94 WHERE day = 1451300400
# UPDATE daily_maxtemps SET Atlanta = 71.96 WHERE day = 1451300400
# UPDATE daily_maxtemps SET Chicago = 41 WHERE day = 1451300400
# UPDATE daily_maxtemps SET Austin = 44.83 WHERE day = 1451300400
# UPDATE daily_maxtemps SET Cleveland = 44.6 WHERE day = 1451300400
# INSERT INTO daily_maxtemps(day) VALUES(1450522800)
# UPDATE daily_maxtemps SET Boston = 40.5 WHERE day = 1450522800
# UPDATE daily_maxtemps SET Atlanta = 51.26 WHERE day = 1450522800
# UPDATE daily_maxtemps SET Chicago = 30.78 WHERE day = 1450522800
# UPDATE daily_maxtemps SET Austin = 64.66 WHERE day = 1450522800
# UPDATE daily_maxtemps SET Cleveland = 32.12 WHERE day = 1450522800
# INSERT INTO daily_maxtemps(day) VALUES(1451559600)
# UPDATE daily_maxtemps SET Boston = 44.39 WHERE day = 1451559600
# UPDATE daily_maxtemps SET Atlanta = 58.78 WHERE day = 1451559600
# UPDATE daily_maxtemps SET Chicago = 28.06 WHERE day = 1451559600
# UPDATE daily_maxtemps SET Austin = 51.88 WHERE day = 1451559600
# UPDATE daily_maxtemps SET Cleveland = 33.84 WHERE day = 1451559600
# INSERT INTO daily_maxtemps(day) VALUES(1452337200)
# UPDATE daily_maxtemps SET Boston = 40.16 WHERE day = 1452337200
# UPDATE daily_maxtemps SET Atlanta = 51.75 WHERE day = 1452337200
# UPDATE daily_maxtemps SET Chicago = 42.42 WHERE day = 1452337200
# UPDATE daily_maxtemps SET Austin = 55.65 WHERE day = 1452337200
# UPDATE daily_maxtemps SET Cleveland = 51.02 WHERE day = 1452337200
# INSERT INTO daily_maxtemps(day) VALUES(1450695600)
# UPDATE daily_maxtemps SET Boston = 52.37 WHERE day = 1450695600
# UPDATE daily_maxtemps SET Atlanta = 58.14 WHERE day = 1450695600
# UPDATE daily_maxtemps SET Chicago = 53.67 WHERE day = 1450695600
# UPDATE daily_maxtemps SET Austin = 73.87 WHERE day = 1450695600
# UPDATE daily_maxtemps SET Cleveland = 52.27 WHERE day = 1450695600
# INSERT INTO daily_maxtemps(day) VALUES(1451473200)
# UPDATE daily_maxtemps SET Boston = 35.23 WHERE day = 1451473200
# UPDATE daily_maxtemps SET Atlanta = 62.87 WHERE day = 1451473200
# UPDATE daily_maxtemps SET Chicago = 30.65 WHERE day = 1451473200
# UPDATE daily_maxtemps SET Austin = 55.49 WHERE day = 1451473200
# UPDATE daily_maxtemps SET Cleveland = 38.51 WHERE day = 1451473200
# INSERT INTO daily_maxtemps(day) VALUES(1451041200)
# UPDATE daily_maxtemps SET Boston = 61.66 WHERE day = 1451041200
# UPDATE daily_maxtemps SET Atlanta = 74.48 WHERE day = 1451041200
# UPDATE daily_maxtemps SET Chicago = 43.08 WHERE day = 1451041200
# UPDATE daily_maxtemps SET Austin = 67.6 WHERE day = 1451041200
# UPDATE daily_maxtemps SET Cleveland = 50.06 WHERE day = 1451041200
# INSERT INTO daily_maxtemps(day) VALUES(1450954800)
# UPDATE daily_maxtemps SET Boston = 67.93 WHERE day = 1450954800
# UPDATE daily_maxtemps SET Atlanta = 71.19 WHERE day = 1450954800
# UPDATE daily_maxtemps SET Chicago = 43.42 WHERE day = 1450954800
# UPDATE daily_maxtemps SET Austin = 73.75 WHERE day = 1450954800
# UPDATE daily_maxtemps SET Cleveland = 60.32 WHERE day = 1450954800
# INSERT INTO daily_maxtemps(day) VALUES(1452510000)
# UPDATE daily_maxtemps SET Boston = 48.96 WHERE day = 1452510000
# UPDATE daily_maxtemps SET Atlanta = 42.47 WHERE day = 1452510000
# UPDATE daily_maxtemps SET Chicago = 24.7 WHERE day = 1452510000
# UPDATE daily_maxtemps SET Austin = 54.24 WHERE day = 1452510000
# UPDATE daily_maxtemps SET Cleveland = 20.17 WHERE day = 1452510000
# INSERT INTO daily_maxtemps(day) VALUES(1450436400)
# UPDATE daily_maxtemps SET Boston = 51.64 WHERE day = 1450436400
# UPDATE daily_maxtemps SET Atlanta = 48.42 WHERE day = 1450436400
# UPDATE daily_maxtemps SET Chicago = 33 WHERE day = 1450436400
# UPDATE daily_maxtemps SET Austin = 56.53 WHERE day = 1450436400
# UPDATE daily_maxtemps SET Cleveland = 36.4 WHERE day = 1450436400
# INSERT INTO daily_maxtemps(day) VALUES(1451905200)
# UPDATE daily_maxtemps SET Boston = 32.35 WHERE day = 1451905200
# UPDATE daily_maxtemps SET Atlanta = 42.95 WHERE day = 1451905200
# UPDATE daily_maxtemps SET Chicago = 30.29 WHERE day = 1451905200
# UPDATE daily_maxtemps SET Austin = 54.76 WHERE day = 1451905200
# UPDATE daily_maxtemps SET Cleveland = 28.54 WHERE day = 1451905200
# INSERT INTO daily_maxtemps(day) VALUES(1451646000)
# UPDATE daily_maxtemps SET Boston = 40 WHERE day = 1451646000
# UPDATE daily_maxtemps SET Atlanta = 46.56 WHERE day = 1451646000
# UPDATE daily_maxtemps SET Chicago = 29.66 WHERE day = 1451646000
# UPDATE daily_maxtemps SET Austin = 47.35 WHERE day = 1451646000
# UPDATE daily_maxtemps SET Cleveland = 31.22 WHERE day = 1451646000
# INSERT INTO daily_maxtemps(day) VALUES(1452250800)
# UPDATE daily_maxtemps SET Boston = 40.4 WHERE day = 1452250800
# UPDATE daily_maxtemps SET Atlanta = 53.33 WHERE day = 1452250800
# UPDATE daily_maxtemps SET Chicago = 42.27 WHERE day = 1452250800
# UPDATE daily_maxtemps SET Austin = 66.39 WHERE day = 1452250800
# UPDATE daily_maxtemps SET Cleveland = 43.79 WHERE day = 1452250800
# INSERT INTO daily_maxtemps(day) VALUES(1452423600)
# UPDATE daily_maxtemps SET Boston = 56.18 WHERE day = 1452423600
# UPDATE daily_maxtemps SET Atlanta = 50.85 WHERE day = 1452423600
# UPDATE daily_maxtemps SET Chicago = 26.17 WHERE day = 1452423600
# UPDATE daily_maxtemps SET Austin = 47.51 WHERE day = 1452423600
# UPDATE daily_maxtemps SET Cleveland = 45.59 WHERE day = 1452423600
# INSERT INTO daily_maxtemps(day) VALUES(1450177200)
# UPDATE daily_maxtemps SET Boston = 60.52 WHERE day = 1450177200
# UPDATE daily_maxtemps SET Atlanta = 71.61 WHERE day = 1450177200
# UPDATE daily_maxtemps SET Chicago = 43.34 WHERE day = 1450177200
# UPDATE daily_maxtemps SET Austin = 74.01 WHERE day = 1450177200
# UPDATE daily_maxtemps SET Cleveland = 48.82 WHERE day = 1450177200
# INSERT INTO daily_maxtemps(day) VALUES(1451732400)
# UPDATE daily_maxtemps SET Boston = 36.71 WHERE day = 1451732400
# UPDATE daily_maxtemps SET Atlanta = 46.6 WHERE day = 1451732400
# UPDATE daily_maxtemps SET Chicago = 31.06 WHERE day = 1451732400
# UPDATE daily_maxtemps SET Austin = 46.09 WHERE day = 1451732400
# UPDATE daily_maxtemps SET Cleveland = 32.58 WHERE day = 1451732400
# INSERT INTO daily_maxtemps(day) VALUES(1452682800)
# UPDATE daily_maxtemps SET Boston = 32.38 WHERE day = 1452682800
# UPDATE daily_maxtemps SET Atlanta = 49.16 WHERE day = 1452682800
# UPDATE daily_maxtemps SET Chicago = 26.69 WHERE day = 1452682800
# UPDATE daily_maxtemps SET Austin = 65.44 WHERE day = 1452682800
# UPDATE daily_maxtemps SET Cleveland = 23.94 WHERE day = 1452682800
# INSERT INTO daily_maxtemps(day) VALUES(1451991600)
# UPDATE daily_maxtemps SET Boston = 23.44 WHERE day = 1451991600
# UPDATE daily_maxtemps SET Atlanta = 42.48 WHERE day = 1451991600
# UPDATE daily_maxtemps SET Chicago = 32.42 WHERE day = 1451991600
# UPDATE daily_maxtemps SET Austin = 54.24 WHERE day = 1451991600
# UPDATE daily_maxtemps SET Cleveland = 27.29 WHERE day = 1451991600
# INSERT INTO daily_maxtemps(day) VALUES(1450782000)
# UPDATE daily_maxtemps SET Boston = 59.05 WHERE day = 1450782000
# UPDATE daily_maxtemps SET Atlanta = 62.78 WHERE day = 1450782000
# UPDATE daily_maxtemps SET Chicago = 43.03 WHERE day = 1450782000
# UPDATE daily_maxtemps SET Austin = 77.87 WHERE day = 1450782000
# UPDATE daily_maxtemps SET Cleveland = 54.88 WHERE day = 1450782000
# INSERT INTO daily_maxtemps(day) VALUES(1450263600)
# UPDATE daily_maxtemps SET Boston = 47.9 WHERE day = 1450263600
# UPDATE daily_maxtemps SET Atlanta = 71.96 WHERE day = 1450263600
# UPDATE daily_maxtemps SET Chicago = 53.18 WHERE day = 1450263600
# UPDATE daily_maxtemps SET Austin = 63.25 WHERE day = 1450263600
# UPDATE daily_maxtemps SET Cleveland = 57.78 WHERE day = 1450263600
# INSERT INTO daily_maxtemps(day) VALUES(1450090800)
# UPDATE daily_maxtemps SET Boston = 55.31 WHERE day = 1450090800
# UPDATE daily_maxtemps SET Atlanta = 67.66 WHERE day = 1450090800
# UPDATE daily_maxtemps SET Chicago = 61.38 WHERE day = 1450090800
# UPDATE daily_maxtemps SET Austin = 74.73 WHERE day = 1450090800
# UPDATE daily_maxtemps SET Cleveland = 64.48 WHERE day = 1450090800
# INSERT INTO daily_maxtemps(day) VALUES(1450868400)
# UPDATE daily_maxtemps SET Boston = 54.76 WHERE day = 1450868400
# UPDATE daily_maxtemps SET Atlanta = 64.45 WHERE day = 1450868400
# UPDATE daily_maxtemps SET Chicago = 59.29 WHERE day = 1450868400
# UPDATE daily_maxtemps SET Austin = 79.99 WHERE day = 1450868400
# UPDATE daily_maxtemps SET Cleveland = 65.56 WHERE day = 1450868400
# "\ninsert_sql = 'INSERT INTO daily_maxtemps (id, city, maxTemp) VALUES (?,?,?)'\n\nfor city, data in cities_max_temp_dict.items():\n    for time, temp in data.items():\n        print parse(time).strftime('%s'), city, temp\n        cur.execute(insert_sql, (parse(time).strftime('%s'), city, temp,))\n"

# %%
df = pd.read_sql('select * from daily_maxtemps', conn)
print df.head()
print df.describe()
print df.columns[1::]
# Out:
#           day  Boston  Atlanta  Cleveland  Austin  Chicago
# 0  1452164400   39.10    58.15      42.86   69.71    40.43
# 1  1451386800   39.43    69.66      50.46   48.68    41.25
# 2  1451127600   55.18    76.41      54.80   76.76    44.32
# 3  1452596400   36.49    50.92      27.82   64.33    21.31
# 4  1452078000   39.37    44.09      36.76   51.61    35.74
#                 day     Boston    Atlanta  Cleveland     Austin    Chicago
# count  3.100000e+01  31.000000  31.000000  31.000000  31.000000  31.000000
# mean   1.451387e+09  45.586774  58.240323  43.671613  62.152258  38.416129
# std    7.855593e+05  10.234138  10.946366  12.704044  10.543351  10.128494
# min    1.450091e+09  23.440000  42.470000  20.170000  44.830000  21.310000
# 25%    1.450739e+09  39.235000  50.005000  33.155000  54.240000  30.470000
# 50%    1.451387e+09  41.530000  58.140000  43.790000  64.330000  40.430000
# 75%    1.452035e+09  53.565000  68.660000  53.535000  71.410000  43.210000
# max    1.452683e+09  67.930000  76.410000  65.560000  79.990000  61.380000
# Index([u'Boston', u'Atlanta', u'Cleveland', u'Austin', u'Chicago'], dtype='object')

# %%
for city in df.columns:
    plt.bar(df.day, df[city])
    plt.show()
