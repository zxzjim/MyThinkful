# %%
print "helloworld"
# Out:
# helloworld

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
dates = pd.date_range('2015-11-10', '2015-11-15')

# %%
dates
# Out:
# DatetimeIndex(['2015-11-10', '2015-11-11', '2015-11-12', '2015-11-13',
#                '2015-11-14', '2015-11-15'],
#               dtype='datetime64[ns]', freq='D')

# %%
atemps = Series([15,14,22,19,18,13], index=dates)

# %%
atemps
# Out:
# 2015-11-10    15
# 2015-11-11    14
# 2015-11-12    22
# 2015-11-13    19
# 2015-11-14    18
# 2015-11-15    13
# Freq: D, dtype: int64

# %%
sdtemps = Series([12,23,18,19,16,14], index=dates)

# %%
temps = DataFrame({'Cologne': atemps, 'Berlin':sdtemps})

# %%
temps
# Out:
#             Berlin  Cologne
# 2015-11-10      12       15
# 2015-11-11      23       14
# 2015-11-12      18       22
# 2015-11-13      19       19
# 2015-11-14      16       18
# 2015-11-15      14       13

# %%
btemps = Series([22,22,20,21,19,19], index=dates)

# %%
btemps
# Out:
# 2015-11-10    22
# 2015-11-11    22
# 2015-11-12    20
# 2015-11-13    21
# 2015-11-14    19
# 2015-11-15    19
# Freq: D, dtype: int64

# %%
temps['Hamburg']=btemps

# %%
temps
# Out:
#             Berlin  Cologne  Hamburg
# 2015-11-10      12       15       22
# 2015-11-11      23       14       22
# 2015-11-12      18       22       20
# 2015-11-13      19       19       21
# 2015-11-14      16       18       19
# 2015-11-15      14       13       19

# %%
temps.Hamburg.drop
# Out:
# <bound method Series.drop of 2015-11-10    22
# 2015-11-11    22
# 2015-11-12    20
# 2015-11-13    21
# 2015-11-14    19
# 2015-11-15    19
# Freq: D, Name: Hamburg, dtype: int64>

# %%
temps
# Out:
#             Berlin  Cologne  Hamburg
# 2015-11-10      12       15       22
# 2015-11-11      23       14       22
# 2015-11-12      18       22       20
# 2015-11-13      19       19       21
# 2015-11-14      16       18       19
# 2015-11-15      14       13       19

# %%
del temps['Hamburg']

# %%
temps
# Out:
#             Berlin  Cologne
# 2015-11-10      12       15
# 2015-11-11      23       14
# 2015-11-12      18       22
# 2015-11-13      19       19
# 2015-11-14      16       18
# 2015-11-15      14       13

# %%
idx = temps.index[2]

# %%
temps.ix[idx, 'Berlin']
# Out:
# 18

# %%
temps.ix[idx:]
# Out:
#             Berlin  Cologne
# 2015-11-12      18       22
# 2015-11-13      19       19
# 2015-11-14      16       18
# 2015-11-15      14       13

# %%
temps.ix[idx:, ['Cologne', 'Berlin']]
# Out:
#             Cologne  Berlin
# 2015-11-12       22      18
# 2015-11-13       19      19
# 2015-11-14       18      16
# 2015-11-15       13      14

# %%
df_withDate = pd.read_csv('somefile.csv', p)
